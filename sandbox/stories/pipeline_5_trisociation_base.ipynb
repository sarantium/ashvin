# %%
# imports

from pathlib import Path
from openai import OpenAI
from dotenv import load_dotenv
import os
import random
import time
import itertools
import pandas as pd
from collections import defaultdict
import re

# %%
# load API key

dotenv_path = Path(r"C:\Storage\python_projects\ashvin\.env")
load_dotenv(dotenv_path=dotenv_path)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
# main constants

GPT_MODEL_TEXT_ALIAS = "gpt-4-turbo-preview"
GPT_MODEL_VISION_ALIAS = "gpt-4-vision-preview"

# additional constants as at 31/01/24
GPT_MODEL_TEXT = "gpt-4-0125-preview"
IMAGE_MODEL = "dall-e-3"
EMBEDDINGS_MODEL = "text-moderation-latest"

# %%
# variations
n = 100
runs = 3

# %%
# simple prompt
base_prompt = f"""
Generate {n} trisociations as a list.
"""

instruction_prompt = f"""
Generate {n} trisociations as a list. No additional comments or elaborations.
"""
format_prompt = f"""
Generate {n} trisociations in the format below. No additional comments or elaborations.
1. Word - Word - Word
2. Word - Word - Word
...
"""
language_prompt = f"""
Generate {n} trisociations in the format below. No additional comments or elaborations.
1. Word (language) - Word (language) - Word (language)
2. Word (language) - Word (language) - Word (language)
...
"""

# %%
#instantiate client
client = OpenAI()

# %%
final_prompt = format_prompt

# %%
# Function to perform a single run and collect data
def perform_run(prompt_text):
    start_time = time.time()
    completion = client.chat.completions.create(
        model=GPT_MODEL_TEXT_ALIAS,
        messages=[
            {"role": "system", "content": prompt_text},
        ]
    )
    end_time = time.time()
    
    trisociation_answer = completion.choices[0].message.content
    execution_time = end_time - start_time
    prompt_tokens = completion.usage.prompt_tokens
    completion_tokens = completion.usage.completion_tokens
    total_tokens = completion.usage.total_tokens

    return {
        'execution_time': execution_time,
        'prompt_tokens': prompt_tokens,
        'completion_tokens': completion_tokens,
        'total_tokens': total_tokens,
        'trisociations': trisociation_answer
    }

# %%
# List to store results from all runs
results = []

# Perform multiple runs
for _ in range(runs):
    result = perform_run(final_prompt)
    results.append(result)

# Calculate average metrics
avg_execution_time = sum(r['execution_time'] for r in results) / runs
avg_prompt_tokens = sum(r['prompt_tokens'] for r in results) / runs
avg_completion_tokens = sum(r['completion_tokens'] for r in results) / runs
avg_total_tokens = sum(r['total_tokens'] for r in results) / runs

# Print out the results
print(f"Average execution time: {avg_execution_time:.2f} seconds")
print(f"Average prompt tokens: {avg_prompt_tokens:.2f}")
print(f"Average completion tokens: {avg_completion_tokens:.2f}")
print(f"Average total tokens: {avg_total_tokens:.2f}")

# Additionally, print each run's trisociations
for i, r in enumerate(results, 1):
    print(f"Run {i} trisociations:\n{r['trisociations']}\n")
# Out:
# Average execution time: 35.21 seconds
# Average prompt tokens: 44.00
# Average completion tokens: 906.67
# Average total tokens: 950.67
# Run 1 trisociations:
# 1. Ocean - Sand - Sunlight
# 2. Mountain - Stars - Solitude
# 3. Laughter - Family - Tea
# 4. Thunder - Rain - Shelter
# 5. Books - Imagination - Journey
# 6. Paint - Canvas - Inspiration
# 7. Piano - Melody - Emotion
# 8. Coffee - Morning - Quiet
# 9. Forest - Mystery - Green
# 10. Snow - Silence - Whiteness
# 11. Bread - Warmth - Home
# 12. Night - Moon - Dreams
# 13. Guitar - Notes - Expression
# 14. Street - Lights - Movement
# 15. Dance - Rhythm - Freedom
# 16. Paper - Ink - Thoughts
# 17. Fire - Warmth - Stories
# 18. Clock - Time - Memories
# 19. Clouds - Sky - Flight
# 20. Gold - Treasure - Quest
# 21. Garden - Flowers - Bees
# 22. Wine - Friends - Conversation
# 23. Ice - Cold - Clarity
# 24. Train - Tracks - Destination
# 25. Chocolate - Sweet - Pleasure
# 26. Keys - Door - Opportunities
# 27. Wind - Leaves - Dance
# 28. Tea - Comfort - Ritual
# 29. Bridge - River - Connection
# 30. Fruit - Fresh - Vitality
# 31. Mountain - Hike - View
# 32. Phone - Messages - Bonds
# 33. Petals - Fragrance - Bloom
# 34. Mirror - Reflection - Truth
# 35. Spice - Flavor - Culture
# 36. Shell - Ocean - Echo
# 37. Map - Journey - Discovery
# 38. Candle - Light - Peace
# 39. Guitar - Strings - Harmony
# 40. Puzzle - Challenge - Solution
# 41. Snowflake - Unique - Beauty
# 42. Rainforest - Diversity - Life
# 43. Feather - Light - Flight
# 44. Compass - Direction - Exploration
# 45. Sunset - Colors - Endings
# 46. Ice Cream - Summer - Joy
# 47. Museum - History - Learning
# 48. Rainbow - Rain - Hope
# 49. Diary - Secrets - Memory
# 50. Balloon - Sky - Release
# 51. Kite - Wind - Play
# 52. Sleep - Dreams - Rest
# 53. Cheese - Wine - Gathering
# 54. Basket - Picnic - Sunshine
# 55. Butterfly - Transformation - Flight
# 56. Lantern - Night - Path
# 57. Waves - Surf - Adventure
# 58. Silk - Soft - Luxury
# 59. Fog - Mystery - Silence
# 60. Glue - Bond - Adhesion
# 61. Compassion - Help - Humanity
# 62. Jewel - Rare - Value
# 63. Owl - Night - Wisdom
# 64. Volcano - Fire - Power
# 65. Honey - Bee - Sweetness
# 66. Telescope - Stars - Beyond
# 67. Socks - Warmth - Comfort
# 68. Poetry - Words - Soul
# 69. Bread - Butter - Simple
# 70. Clocks - Time - Age
# 71. Seeds - Growth - Life
# 72. Soap - Clean - Fresh
# 73. Chocolate - Milk - Happiness
# 74. Snowboard - Snow - Thrill
# 75. Key - Lock - Security
# 76. Dreams - Night - Mystery
# 77. Whale - Ocean - Depth
# 78. Fog - Morning - Enigma
# 79. Needle - Thread - Craft
# 80. Book - Library - Knowledge
# 81. Iceberg - Cold - Hidden
# 82. Desert - Sand - Mirage
# 83. Sculpture - Stone - Art
# 84. Hammock - Trees - Relaxation
# 85. Compass - Map - Adventure
# 86. Quill - Ink - History
# 87. Lighthouse - Sea - Guide
# 88. Candle - Flame - Meditation
# 89. Robot - Future - Technology
# 90. Skateboard - Concrete - Freedom
# 91. Fountain - Water - Serenity
# 92. Telescope - Sky - Exploration
# 93. Rainbow - Clouds - Beauty
# 94. Motorcycle - Road - Wind
# 95. Castle - History - Mystery
# 96. Backpack - Travel - Adventure
# 97. Web - Spider - Connection
# 98. Storm - Lightning - Power
# 99. Farm - Harvest - Nature
# 100. Dreamcatcher - Dreams - Protection
#
# Run 2 trisociations:
# 1. Elephant - Sky - Calculus
# 2. Snow - Violin - Molecule
# 3. Pyramid - Thunder - Whisper
# 4. Pizza - Galaxy - Formula
# 5. Desert - Ocean - Keyboard
# 6. Castle - Quantum - Feather
# 7. Volcano - Silk - Equation
# 8. Rainbow - Candle - Circuit
# 9. Diamond - Fog - Sonnet
# 10. Glacier - Perfume - Byte
# 11. Lion - Clock - Binary
# 12. Forest - Jazz - Prism
# 13. Sand - Piano - Atom
# 14. Moon - Lace - Algorithm
# 15. Star - River - Metaphor
# 16. Sunflower - Avalanche - Pixel
# 17. Wind - Gold - Symphony
# 18. Mountain - Tiger - Paintbrush
# 19. Butterfly - Storm - Poetry
# 20. Fire - Wool - Matrix
# 21. Cloud - Rose - Compass
# 22. Ice - Guitar - Neuron
# 23. Comet - Silk - Riddle
# 24. Aurora - Spice - Blueprint
# 25. Ocean - Mirror - Logic
# 26. Thunderstorm - Chocolate - Code
# 27. Eclipse - Feather - Harmony
# 28. Coral - Wheat - Puzzle
# 29. Bamboo - Fog - Sculpture
# 30. Wolf - Piano - Network
# 31. Dolphin - Book - Chip
# 32. Lightning - Pearl - Graph
# 33. Cave - Snowflake - Theorem
# 34. Eagle - Tea - Framework
# 35. Cactus - Balloon - Lyric
# 36. Whale - Library - Quantum
# 37. Lava - Lace - Legend
# 38. Oasis - Clock - Labyrinth
# 39. Desert - Spice - Magnet
# 40. Tide - Paint - Protocol
# 41. Palm - Hammer - Verse
# 42. Falcon - Map - Silicon
# 43. Seal - Thunder - Patent
# 44. Jungle - Frost - Lens
# 45. Marsh - Flame - Module
# 46. Stream - Wheat - Circuit
# 47. Reef - Ivory - Console
# 48. Geyser - Quill - Array
# 49. Fox - Velvet - Equation
# 50. Grass - Moonlight - Cipher
# 51. Squirrel - Stream - Variable
# 52. Mountain - Candle - Framework
# 53. Platypus - Frost - Algorithm
# 54. Firefly - Clay - Pixel
# 55. Penguin - Spice - Interface
# 56. Canyon - Quilt - Quantum
# 57. Pebble - Snowstorm - Array
# 58. Valley - Thunder - Buffer
# 59. Iceberg - Silk - Vector
# 60. Volcano - Puzzle - Portal
# 61. Coral - Wind - Byte
# 62. Bamboo - Perfume - Socket
# 63. Dandelion - River - Mainframe
# 64. Tornado - Marble - Script
# 65. Owl - Raindrop - Index
# 66. Glacier - Fossil - Kernel
# 67. Tulip - Blizzard - Operand
# 68. Wolf - Mirage - Stack
# 69. Cave - Lava - Node
# 70. Comet - Wheat - Query
# 71. Aurora - Ribbon - Toggle
# 72. Stream - Vortex - Batch
# 73. Robin - Frost - Gateway
# 74. Gorge - Spice - Encrypt
# 75. Brook - Quartz - Pipeline
# 76. Lake - Thunder - Allocate
# 77. Desert - Oasis - Hash
# 78. Jungle - Breeze - Compile
# 79. Mountain - Cave - Execute
# 80. Cloud - Dune - Deploy
# 81. River - Delta - Link
# 82. Meadow - Glisten - Fetch
# 83. Forest - Echo - Thread
# 84. Prairie - Mist - Merge
# 85. Canyon - Glow - Serialize
# 86. Volcano - Ash - Iterate
# 87. Waterfall - Rainbow - Resolve
# 88. Iceberg - Penguin - Transmit
# 89. Mesa - Dust - Randomize
# 90. Geyser - Steam - Debug
# 91. Reef - Tide - Access
# 92. Fjord - Glacial - Flush
# 93. Plateau - Horizon - Release
# 94. Glacier - Seal - Hook
# 95. Archipelago - Current - Sync
# 96. Oasis - Mirage - Await
# 97. Tundra - Woolly - Trigger
# 98. Savannah - Lion - Schedule
# 99. Rainforest - Monkey - Abort
# 100. Taiga - Lynx - Function
#
# Run 3 trisociations:
# 1. Ocean - Painting - Algorithm
# 2. Coffee - Galaxy - Violin
# 3. Mountain - Code - Theater
# 4. Forest - Symphony - Quantum
# 5. Desert - Clockwork - Philosophy
# 6. Iceberg - Novel - Electricity
# 7. River - Sculpture - Neon
# 8. Thunder - Ballet - Silicon
# 9. Eclipse - Jazz - Firewall
# 10. Glacier - Poetry - Pixel
# 11. Volcano - Opera - Binary
# 12. Canyon - Fresco - Hologram
# 13. Monsoon - Sonnet - Laser
# 14. Aurora - Blues - Microchip
# 15. Tornado - Haiku - Cyber
# 16. Prairie - Rock - Tensor
# 17. Tempest - Elegy - Algorithmic
# 18. Reef - Folk - Virtual
# 19. Wetland - Reggae - Quantum
# 20. Fjord - Limerick - Satellite
# 21. Savannah - Gospel - Nanotech
# 22. Marsh - Punk - Blockchain
# 23. Oasis - Sestina - Drone
# 24. Waterfall - Disco - Cryptography
# 25. Delta - Ballad - Augmented
# 26. Mesa - Classical - Digital
# 27. Plateau - Epic - Fiber
# 28. Gorge - Grunge - Protocol
# 29. Butte - Rhythm - Interface
# 30. Archipelago - Lyric - Cloud
# 31. Icefield - Melody - Bit
# 32. Moor - Harmony - Network
# 33. Rainforest - Beat - Encryption
# 34. Steppe - Rap - Modem
# 35. Tundra - Chorus - Application
# 36. Basin - Techno - Pixelated
# 37. Dune - Sonata - Connectivity
# 38. Valley - Soul - Bandwidth
# 39. Peak - Dubstep - Compiler
# 40. Cave - Acoustic - Data
# 41. Island - Jazz - Syntax
# 42. Pond - Indie - Software
# 43. Riverbank - Ambient - Server
# 44. Lake - Bluegrass - Programming
# 45. Stream - Country - Boot
# 46. Swamp - Funk - Virtual Reality
# 47. Bay - Swing - Logic
# 48. Gulf - Electro - Interface
# 49. Sea - Metal - Cloud Computing
# 50. Oceanic - Pop - Quantum Computing
# 51. Lagoon - Reggaeton - Ethernet
# 52. Firth - Symphony - Digital Signature
# 53. Sound - Opera - AI
# 54. Channel - Ballad - Machine Learning
# 55. Strait - Chant - Algorithm
# 56. Fjord - Didactic - Robotics
# 57. Creek - Folklore - Software Development
# 58. Reservoir - Lieder - Parallel Processing
# 59. Estuary - Motet - Data Science
# 60. Spring - Ragtime - Internet of Things
# 61. Geysir - Ska - Big Data
# 62. Watercourse - Trance - Deep Learning
# 63. Rivulet - Minstrel - User Interface
# 64. Brook - Anthem - Network Security
# 65. Runnel - Oratorio - Quantum Encryption
# 66. Rill - Cantata - Cloud Storage
# 67. Raindrop - Madrigal - Cryptanalysis
# 68. Dew - Spiritual - Augmented Reality
# 69. Mist - Baroque - Virtual Machine
# 70. Cloud - Concerto - Automated Reasoning
# 71. Drizzle - Rhapsody - Peer-to-Peer
# 72. Shower - Nocturne - Blockchain Technology
# 73. Storm - Serenade - Distributed Ledger
# 74. Monsoon - Caprice - Encryption Algorithm
# 75. Hurricane - Aria - Cybersecurity
# 76. Cyclone - Overture - Data Encryption
# 77. Typhoon - Recitative - Internet Protocol
# 78. Gale - Fugue - Semantic Web
# 79. Wind - Impromptu - Artificial Neural Network
# 80. Breeze - Ballade - Deep Web
# 81. Zephyr - Carillon - Cloud Hosting
# 82. Draft - Lullaby - Network Layer
# 83. Gust - Toccata - Cryptocurrency
# 84. Blast - Bolero - Quantum Circuit
# 85. Squall - Dirge - User Experience
# 86. Storm - Intermezzo - Silicon Valley
# 87. Tempest - Canticle - Virtual Assistant
# 88. Blizzard - Mazurka - Open Source
# 89. Snowstorm - Rondo - Data Mining
# 90. Flurry - Sarabande - Digital Wallet
# 91. Avalanche - Berceuse - Peer-to-Peer Network
# 92. Frost - Courante - Smart Contract
# 93. Ice - Minuet - Machine-to-Machine
# 94. Sleet - Passacaglia - Internet Privacy
# 95. Snow - Pavane - Cryptographic Hash
# 96. Hail - Gigue - Internet Backbone
# 97. Glaze - Allemande - Distributed Computing
# 98. Rime - Hornpipe - Application Layer
# 99. Blizzard - Polonaise - Secure Socket Layer
# 100. Snowfall - Chaconne - Network Architecture

# %%
# Function to analyze trisociations for duplicate words within each run
def analyze_duplicates_per_run(results):
    for i, result in enumerate(results, 1):
        trisociations = result['trisociations'].strip()  # Ensure to strip whitespace for clean splitting
        word_map = defaultdict(lambda: {'count': 0, 'trisociation_indices': []})

        # Split trisociations and analyze words
        trisociation_list = trisociations.split('\n')
        for index, trisociation in enumerate(trisociation_list, start=1):
            # Assuming trisociations are exactly "word - word - word" format
            words = trisociation.replace(' - ', ' ').split()  # Split all words while removing " - "
            for word in words:
                word_map[word]['count'] += 1
                word_map[word]['trisociation_indices'].append(index)

        # Filter for duplicates within this run
        duplicates = {word: info for word, info in word_map.items() if info['count'] > 1}

        # Print out duplicates and their details for this run
        print(f"Run {i}: Duplicate word analysis")
        if duplicates:  # If there are any duplicates
            for word, info in duplicates.items():
                indices = ', '.join(map(str, info['trisociation_indices']))
                print(f"Word '{word}' is used {info['count']} times in trisociations: {indices}")
        else:
            print("No duplicate words found in this run.")
        print("\n")  # Add a newline for better separation between runs

# After collecting all results, call the function
analyze_duplicates_per_run(results)
# Out:
# Run 1: Duplicate word analysis
# Word 'Ocean' is used 3 times in trisociations: 1, 36, 77
# Word 'Sand' is used 2 times in trisociations: 1, 82
# Word 'Mountain' is used 2 times in trisociations: 2, 31
# Word 'Stars' is used 2 times in trisociations: 2, 66
# Word 'Tea' is used 2 times in trisociations: 3, 28
# Word 'Rain' is used 2 times in trisociations: 4, 48
# Word 'Journey' is used 2 times in trisociations: 5, 37
# Word 'Morning' is used 2 times in trisociations: 8, 78
# Word 'Mystery' is used 4 times in trisociations: 9, 59, 76, 95
# Word 'Snow' is used 2 times in trisociations: 10, 74
# Word 'Silence' is used 2 times in trisociations: 10, 59
# Word 'Bread' is used 2 times in trisociations: 11, 69
# Word 'Warmth' is used 3 times in trisociations: 11, 17, 67
# Word 'Night' is used 4 times in trisociations: 12, 56, 63, 76
# Word 'Dreams' is used 4 times in trisociations: 12, 52, 76, 100
# Word 'Guitar' is used 2 times in trisociations: 13, 39
# Word 'Dance' is used 2 times in trisociations: 15, 27
# Word 'Freedom' is used 2 times in trisociations: 15, 90
# Word 'Ink' is used 2 times in trisociations: 16, 86
# Word 'Fire' is used 2 times in trisociations: 17, 64
# Word 'Time' is used 2 times in trisociations: 18, 70
# Word 'Clouds' is used 2 times in trisociations: 19, 93
# Word 'Sky' is used 3 times in trisociations: 19, 50, 92
# Word 'Flight' is used 3 times in trisociations: 19, 43, 55
# Word 'Wine' is used 2 times in trisociations: 22, 53
# Word 'Ice' is used 2 times in trisociations: 23, 46
# Word 'Cold' is used 2 times in trisociations: 23, 81
# Word 'Chocolate' is used 2 times in trisociations: 25, 73
# Word 'Wind' is used 3 times in trisociations: 27, 51, 94
# Word 'Comfort' is used 2 times in trisociations: 28, 67
# Word 'Connection' is used 2 times in trisociations: 29, 97
# Word 'Fresh' is used 2 times in trisociations: 30, 72
# Word 'Map' is used 2 times in trisociations: 37, 85
# Word 'Candle' is used 2 times in trisociations: 38, 88
# Word 'Light' is used 2 times in trisociations: 38, 43
# Word 'Beauty' is used 2 times in trisociations: 41, 93
# Word 'Life' is used 2 times in trisociations: 42, 71
# Word 'Compass' is used 2 times in trisociations: 44, 85
# Word 'Exploration' is used 2 times in trisociations: 44, 92
# Word 'History' is used 3 times in trisociations: 47, 86, 95
# Word 'Rainbow' is used 2 times in trisociations: 48, 93
# Word 'Adventure' is used 3 times in trisociations: 57, 85, 96
# Word 'Fog' is used 2 times in trisociations: 59, 78
# Word 'Power' is used 2 times in trisociations: 64, 98
# Word 'Telescope' is used 2 times in trisociations: 66, 92
#
#
# Run 2: Duplicate word analysis
# Word 'Thunder' is used 4 times in trisociations: 3, 43, 58, 76
# Word 'Desert' is used 3 times in trisociations: 5, 39, 77
# Word 'Ocean' is used 2 times in trisociations: 5, 25
# Word 'Quantum' is used 3 times in trisociations: 6, 36, 56
# Word 'Feather' is used 2 times in trisociations: 6, 27
# Word 'Volcano' is used 3 times in trisociations: 7, 60, 86
# Word 'Silk' is used 3 times in trisociations: 7, 23, 59
# Word 'Equation' is used 2 times in trisociations: 7, 49
# Word 'Rainbow' is used 2 times in trisociations: 8, 87
# Word 'Candle' is used 2 times in trisociations: 8, 52
# Word 'Circuit' is used 2 times in trisociations: 8, 46
# Word 'Fog' is used 2 times in trisociations: 9, 29
# Word 'Glacier' is used 3 times in trisociations: 10, 66, 94
# Word 'Perfume' is used 2 times in trisociations: 10, 62
# Word 'Byte' is used 2 times in trisociations: 10, 61
# Word 'Lion' is used 2 times in trisociations: 11, 98
# Word 'Clock' is used 2 times in trisociations: 11, 38
# Word 'Forest' is used 2 times in trisociations: 12, 83
# Word 'Piano' is used 2 times in trisociations: 13, 30
# Word 'Lace' is used 2 times in trisociations: 14, 37
# Word 'Algorithm' is used 2 times in trisociations: 14, 53
# Word 'River' is used 3 times in trisociations: 15, 63, 81
# Word 'Pixel' is used 2 times in trisociations: 16, 54
# Word 'Wind' is used 2 times in trisociations: 17, 61
# Word 'Mountain' is used 3 times in trisociations: 18, 52, 79
# Word 'Cloud' is used 2 times in trisociations: 21, 80
# Word 'Comet' is used 2 times in trisociations: 23, 70
# Word 'Aurora' is used 2 times in trisociations: 24, 71
# Word 'Spice' is used 4 times in trisociations: 24, 39, 55, 74
# Word 'Coral' is used 2 times in trisociations: 28, 61
# Word 'Wheat' is used 3 times in trisociations: 28, 46, 70
# Word 'Puzzle' is used 2 times in trisociations: 28, 60
# Word 'Bamboo' is used 2 times in trisociations: 29, 62
# Word 'Wolf' is used 2 times in trisociations: 30, 68
# Word 'Cave' is used 3 times in trisociations: 33, 69, 79
# Word 'Framework' is used 2 times in trisociations: 34, 52
# Word 'Lava' is used 2 times in trisociations: 37, 69
# Word 'Oasis' is used 3 times in trisociations: 38, 77, 96
# Word 'Tide' is used 2 times in trisociations: 40, 91
# Word 'Seal' is used 2 times in trisociations: 43, 94
# Word 'Jungle' is used 2 times in trisociations: 44, 78
# Word 'Frost' is used 3 times in trisociations: 44, 53, 73
# Word 'Stream' is used 3 times in trisociations: 46, 51, 72
# Word 'Reef' is used 2 times in trisociations: 47, 91
# Word 'Geyser' is used 2 times in trisociations: 48, 90
# Word 'Array' is used 2 times in trisociations: 48, 57
# Word 'Penguin' is used 2 times in trisociations: 55, 88
# Word 'Canyon' is used 2 times in trisociations: 56, 85
# Word 'Iceberg' is used 2 times in trisociations: 59, 88
# Word 'Mirage' is used 2 times in trisociations: 68, 96
#
#
# Run 3: Duplicate word analysis
# Word 'Algorithm' is used 3 times in trisociations: 1, 55, 74
# Word 'Symphony' is used 2 times in trisociations: 4, 52
# Word 'Quantum' is used 5 times in trisociations: 4, 19, 50, 65, 84
# Word 'Silicon' is used 2 times in trisociations: 8, 86
# Word 'Jazz' is used 2 times in trisociations: 9, 41
# Word 'Opera' is used 2 times in trisociations: 11, 53
# Word 'Monsoon' is used 2 times in trisociations: 13, 74
# Word 'Tempest' is used 2 times in trisociations: 17, 87
# Word 'Virtual' is used 4 times in trisociations: 18, 46, 69, 87
# Word 'Fjord' is used 2 times in trisociations: 20, 56
# Word 'Blockchain' is used 2 times in trisociations: 22, 72
# Word 'Ballad' is used 2 times in trisociations: 25, 54
# Word 'Augmented' is used 2 times in trisociations: 25, 68
# Word 'Digital' is used 3 times in trisociations: 26, 52, 90
# Word 'Protocol' is used 2 times in trisociations: 28, 77
# Word 'Interface' is used 3 times in trisociations: 29, 48, 63
# Word 'Cloud' is used 5 times in trisociations: 30, 49, 66, 70, 81
# Word 'Network' is used 6 times in trisociations: 32, 64, 79, 82, 91, 100
# Word 'Encryption' is used 4 times in trisociations: 33, 65, 74, 76
# Word 'Application' is used 2 times in trisociations: 35, 98
# Word 'Valley' is used 2 times in trisociations: 38, 86
# Word 'Data' is used 5 times in trisociations: 40, 59, 61, 76, 89
# Word 'Software' is used 2 times in trisociations: 42, 57
# Word 'Reality' is used 2 times in trisociations: 46, 68
# Word 'Computing' is used 3 times in trisociations: 49, 50, 97
# Word 'Machine' is used 2 times in trisociations: 54, 69
# Word 'Learning' is used 2 times in trisociations: 54, 62
# Word 'Internet' is used 4 times in trisociations: 60, 77, 94, 96
# Word 'Deep' is used 2 times in trisociations: 62, 80
# Word 'User' is used 2 times in trisociations: 63, 85
# Word 'Peer-to-Peer' is used 2 times in trisociations: 71, 91
# Word 'Storm' is used 2 times in trisociations: 73, 86
# Word 'Distributed' is used 2 times in trisociations: 73, 97
# Word 'Web' is used 2 times in trisociations: 78, 80
# Word 'Layer' is used 3 times in trisociations: 82, 98, 99
# Word 'Blizzard' is used 2 times in trisociations: 88, 99

# %%
# Function to analyze trisociations for duplicate words within each run
def analyze_duplicates_across_runs(results):
    # Initialize a dictionary to track word occurrences across all runs and trisociations
    all_words_map = defaultdict(lambda: {'count': 0, 'details': []})

    for run_index, result in enumerate(results, start=1):
        trisociations = result['trisociations'].strip()  # Clean up whitespace
        trisociation_list = trisociations.split('\n')

        for trisociation_index, trisociation in enumerate(trisociation_list, start=1):
            # Remove leading indices like "1." from each trisociation before splitting
            cleaned_trisociation = re.sub(r'^\d+\.\s*', '', trisociation)
            words = cleaned_trisociation.replace(' - ', ' ').split()  # Extract words, removing " - "
            for word in words:
                all_words_map[word]['count'] += 1
                all_words_map[word]['details'].append((run_index, trisociation_index))

    # Filter for words appearing in more than one trisociation across all runs
    duplicates_across_runs = {word: info for word, info in all_words_map.items() if info['count'] > 1}

    # Print out the results
    if duplicates_across_runs:
        print("Duplicate words across runs and their occurrences:")
        for word, info in duplicates_across_runs.items():
            print(f"Word '{word}' is used {info['count']} times across runs.")
            for detail in info['details']:
                print(f" - In Run {detail[0]}, Trisociation {detail[1]}")
            print()  # Blank line for readability
    else:
        print("No duplicate words found across all runs.")

# After collecting all results, call the function
analyze_duplicates_across_runs(results)
# Out:
# Duplicate words across runs and their occurrences:
# Word 'Ocean' is used 6 times across runs.
#  - In Run 1, Trisociation 1
#  - In Run 1, Trisociation 36
#  - In Run 1, Trisociation 77
#  - In Run 2, Trisociation 5
#  - In Run 2, Trisociation 25
#  - In Run 3, Trisociation 1
#
# Word 'Sand' is used 3 times across runs.
#  - In Run 1, Trisociation 1
#  - In Run 1, Trisociation 82
#  - In Run 2, Trisociation 13
#
# Word 'Mountain' is used 6 times across runs.
#  - In Run 1, Trisociation 2
#  - In Run 1, Trisociation 31
#  - In Run 2, Trisociation 18
#  - In Run 2, Trisociation 52
#  - In Run 2, Trisociation 79
#  - In Run 3, Trisociation 3
#
# Word 'Stars' is used 2 times across runs.
#  - In Run 1, Trisociation 2
#  - In Run 1, Trisociation 66
#
# Word 'Tea' is used 3 times across runs.
#  - In Run 1, Trisociation 3
#  - In Run 1, Trisociation 28
#  - In Run 2, Trisociation 34
#
# Word 'Thunder' is used 6 times across runs.
#  - In Run 1, Trisociation 4
#  - In Run 2, Trisociation 3
#  - In Run 2, Trisociation 43
#  - In Run 2, Trisociation 58
#  - In Run 2, Trisociation 76
#  - In Run 3, Trisociation 8
#
# Word 'Rain' is used 2 times across runs.
#  - In Run 1, Trisociation 4
#  - In Run 1, Trisociation 48
#
# Word 'Journey' is used 2 times across runs.
#  - In Run 1, Trisociation 5
#  - In Run 1, Trisociation 37
#
# Word 'Paint' is used 2 times across runs.
#  - In Run 1, Trisociation 6
#  - In Run 2, Trisociation 40
#
# Word 'Piano' is used 3 times across runs.
#  - In Run 1, Trisociation 7
#  - In Run 2, Trisociation 13
#  - In Run 2, Trisociation 30
#
# Word 'Melody' is used 2 times across runs.
#  - In Run 1, Trisociation 7
#  - In Run 3, Trisociation 31
#
# Word 'Coffee' is used 2 times across runs.
#  - In Run 1, Trisociation 8
#  - In Run 3, Trisociation 2
#
# Word 'Morning' is used 2 times across runs.
#  - In Run 1, Trisociation 8
#  - In Run 1, Trisociation 78
#
# Word 'Forest' is used 4 times across runs.
#  - In Run 1, Trisociation 9
#  - In Run 2, Trisociation 12
#  - In Run 2, Trisociation 83
#  - In Run 3, Trisociation 4
#
# Word 'Mystery' is used 4 times across runs.
#  - In Run 1, Trisociation 9
#  - In Run 1, Trisociation 59
#  - In Run 1, Trisociation 76
#  - In Run 1, Trisociation 95
#
# Word 'Snow' is used 4 times across runs.
#  - In Run 1, Trisociation 10
#  - In Run 1, Trisociation 74
#  - In Run 2, Trisociation 2
#  - In Run 3, Trisociation 95
#
# Word 'Silence' is used 2 times across runs.
#  - In Run 1, Trisociation 10
#  - In Run 1, Trisociation 59
#
# Word 'Bread' is used 2 times across runs.
#  - In Run 1, Trisociation 11
#  - In Run 1, Trisociation 69
#
# Word 'Warmth' is used 3 times across runs.
#  - In Run 1, Trisociation 11
#  - In Run 1, Trisociation 17
#  - In Run 1, Trisociation 67
#
# Word 'Night' is used 4 times across runs.
#  - In Run 1, Trisociation 12
#  - In Run 1, Trisociation 56
#  - In Run 1, Trisociation 63
#  - In Run 1, Trisociation 76
#
# Word 'Moon' is used 2 times across runs.
#  - In Run 1, Trisociation 12
#  - In Run 2, Trisociation 14
#
# Word 'Dreams' is used 4 times across runs.
#  - In Run 1, Trisociation 12
#  - In Run 1, Trisociation 52
#  - In Run 1, Trisociation 76
#  - In Run 1, Trisociation 100
#
# Word 'Guitar' is used 3 times across runs.
#  - In Run 1, Trisociation 13
#  - In Run 1, Trisociation 39
#  - In Run 2, Trisociation 22
#
# Word 'Dance' is used 2 times across runs.
#  - In Run 1, Trisociation 15
#  - In Run 1, Trisociation 27
#
# Word 'Rhythm' is used 2 times across runs.
#  - In Run 1, Trisociation 15
#  - In Run 3, Trisociation 29
#
# Word 'Freedom' is used 2 times across runs.
#  - In Run 1, Trisociation 15
#  - In Run 1, Trisociation 90
#
# Word 'Ink' is used 2 times across runs.
#  - In Run 1, Trisociation 16
#  - In Run 1, Trisociation 86
#
# Word 'Fire' is used 3 times across runs.
#  - In Run 1, Trisociation 17
#  - In Run 1, Trisociation 64
#  - In Run 2, Trisociation 20
#
# Word 'Clock' is used 3 times across runs.
#  - In Run 1, Trisociation 18
#  - In Run 2, Trisociation 11
#  - In Run 2, Trisociation 38
#
# Word 'Time' is used 2 times across runs.
#  - In Run 1, Trisociation 18
#  - In Run 1, Trisociation 70
#
# Word 'Clouds' is used 2 times across runs.
#  - In Run 1, Trisociation 19
#  - In Run 1, Trisociation 93
#
# Word 'Sky' is used 4 times across runs.
#  - In Run 1, Trisociation 19
#  - In Run 1, Trisociation 50
#  - In Run 1, Trisociation 92
#  - In Run 2, Trisociation 1
#
# Word 'Flight' is used 3 times across runs.
#  - In Run 1, Trisociation 19
#  - In Run 1, Trisociation 43
#  - In Run 1, Trisociation 55
#
# Word 'Gold' is used 2 times across runs.
#  - In Run 1, Trisociation 20
#  - In Run 2, Trisociation 17
#
# Word 'Wine' is used 2 times across runs.
#  - In Run 1, Trisociation 22
#  - In Run 1, Trisociation 53
#
# Word 'Ice' is used 4 times across runs.
#  - In Run 1, Trisociation 23
#  - In Run 1, Trisociation 46
#  - In Run 2, Trisociation 22
#  - In Run 3, Trisociation 93
#
# Word 'Cold' is used 2 times across runs.
#  - In Run 1, Trisociation 23
#  - In Run 1, Trisociation 81
#
# Word 'Chocolate' is used 3 times across runs.
#  - In Run 1, Trisociation 25
#  - In Run 1, Trisociation 73
#  - In Run 2, Trisociation 26
#
# Word 'Wind' is used 6 times across runs.
#  - In Run 1, Trisociation 27
#  - In Run 1, Trisociation 51
#  - In Run 1, Trisociation 94
#  - In Run 2, Trisociation 17
#  - In Run 2, Trisociation 61
#  - In Run 3, Trisociation 79
#
# Word 'Comfort' is used 2 times across runs.
#  - In Run 1, Trisociation 28
#  - In Run 1, Trisociation 67
#
# Word 'River' is used 5 times across runs.
#  - In Run 1, Trisociation 29
#  - In Run 2, Trisociation 15
#  - In Run 2, Trisociation 63
#  - In Run 2, Trisociation 81
#  - In Run 3, Trisociation 7
#
# Word 'Connection' is used 2 times across runs.
#  - In Run 1, Trisociation 29
#  - In Run 1, Trisociation 97
#
# Word 'Fresh' is used 2 times across runs.
#  - In Run 1, Trisociation 30
#  - In Run 1, Trisociation 72
#
# Word 'Mirror' is used 2 times across runs.
#  - In Run 1, Trisociation 34
#  - In Run 2, Trisociation 25
#
# Word 'Spice' is used 5 times across runs.
#  - In Run 1, Trisociation 35
#  - In Run 2, Trisociation 24
#  - In Run 2, Trisociation 39
#  - In Run 2, Trisociation 55
#  - In Run 2, Trisociation 74
#
# Word 'Echo' is used 2 times across runs.
#  - In Run 1, Trisociation 36
#  - In Run 2, Trisociation 83
#
# Word 'Map' is used 3 times across runs.
#  - In Run 1, Trisociation 37
#  - In Run 1, Trisociation 85
#  - In Run 2, Trisociation 42
#
# Word 'Candle' is used 4 times across runs.
#  - In Run 1, Trisociation 38
#  - In Run 1, Trisociation 88
#  - In Run 2, Trisociation 8
#  - In Run 2, Trisociation 52
#
# Word 'Light' is used 2 times across runs.
#  - In Run 1, Trisociation 38
#  - In Run 1, Trisociation 43
#
# Word 'Harmony' is used 3 times across runs.
#  - In Run 1, Trisociation 39
#  - In Run 2, Trisociation 27
#  - In Run 3, Trisociation 32
#
# Word 'Puzzle' is used 3 times across runs.
#  - In Run 1, Trisociation 40
#  - In Run 2, Trisociation 28
#  - In Run 2, Trisociation 60
#
# Word 'Snowflake' is used 2 times across runs.
#  - In Run 1, Trisociation 41
#  - In Run 2, Trisociation 33
#
# Word 'Beauty' is used 2 times across runs.
#  - In Run 1, Trisociation 41
#  - In Run 1, Trisociation 93
#
# Word 'Rainforest' is used 3 times across runs.
#  - In Run 1, Trisociation 42
#  - In Run 2, Trisociation 99
#  - In Run 3, Trisociation 33
#
# Word 'Life' is used 2 times across runs.
#  - In Run 1, Trisociation 42
#  - In Run 1, Trisociation 71
#
# Word 'Feather' is used 3 times across runs.
#  - In Run 1, Trisociation 43
#  - In Run 2, Trisociation 6
#  - In Run 2, Trisociation 27
#
# Word 'Compass' is used 3 times across runs.
#  - In Run 1, Trisociation 44
#  - In Run 1, Trisociation 85
#  - In Run 2, Trisociation 21
#
# Word 'Exploration' is used 2 times across runs.
#  - In Run 1, Trisociation 44
#  - In Run 1, Trisociation 92
#
# Word 'History' is used 3 times across runs.
#  - In Run 1, Trisociation 47
#  - In Run 1, Trisociation 86
#  - In Run 1, Trisociation 95
#
# Word 'Learning' is used 3 times across runs.
#  - In Run 1, Trisociation 47
#  - In Run 3, Trisociation 54
#  - In Run 3, Trisociation 62
#
# Word 'Rainbow' is used 4 times across runs.
#  - In Run 1, Trisociation 48
#  - In Run 1, Trisociation 93
#  - In Run 2, Trisociation 8
#  - In Run 2, Trisociation 87
#
# Word 'Balloon' is used 2 times across runs.
#  - In Run 1, Trisociation 50
#  - In Run 2, Trisociation 35
#
# Word 'Release' is used 2 times across runs.
#  - In Run 1, Trisociation 50
#  - In Run 2, Trisociation 93
#
# Word 'Butterfly' is used 2 times across runs.
#  - In Run 1, Trisociation 55
#  - In Run 2, Trisociation 19
#
# Word 'Adventure' is used 3 times across runs.
#  - In Run 1, Trisociation 57
#  - In Run 1, Trisociation 85
#  - In Run 1, Trisociation 96
#
# Word 'Silk' is used 4 times across runs.
#  - In Run 1, Trisociation 58
#  - In Run 2, Trisociation 7
#  - In Run 2, Trisociation 23
#  - In Run 2, Trisociation 59
#
# Word 'Fog' is used 4 times across runs.
#  - In Run 1, Trisociation 59
#  - In Run 1, Trisociation 78
#  - In Run 2, Trisociation 9
#  - In Run 2, Trisociation 29
#
# Word 'Owl' is used 2 times across runs.
#  - In Run 1, Trisociation 63
#  - In Run 2, Trisociation 65
#
# Word 'Volcano' is used 5 times across runs.
#  - In Run 1, Trisociation 64
#  - In Run 2, Trisociation 7
#  - In Run 2, Trisociation 60
#  - In Run 2, Trisociation 86
#  - In Run 3, Trisociation 11
#
# Word 'Power' is used 2 times across runs.
#  - In Run 1, Trisociation 64
#  - In Run 1, Trisociation 98
#
# Word 'Telescope' is used 2 times across runs.
#  - In Run 1, Trisociation 66
#  - In Run 1, Trisociation 92
#
# Word 'Poetry' is used 3 times across runs.
#  - In Run 1, Trisociation 68
#  - In Run 2, Trisociation 19
#  - In Run 3, Trisociation 10
#
# Word 'Soul' is used 2 times across runs.
#  - In Run 1, Trisociation 68
#  - In Run 3, Trisociation 38
#
# Word 'Security' is used 2 times across runs.
#  - In Run 1, Trisociation 75
#  - In Run 3, Trisociation 64
#
# Word 'Whale' is used 2 times across runs.
#  - In Run 1, Trisociation 77
#  - In Run 2, Trisociation 36
#
# Word 'Thread' is used 2 times across runs.
#  - In Run 1, Trisociation 79
#  - In Run 2, Trisociation 83
#
# Word 'Book' is used 2 times across runs.
#  - In Run 1, Trisociation 80
#  - In Run 2, Trisociation 31
#
# Word 'Library' is used 2 times across runs.
#  - In Run 1, Trisociation 80
#  - In Run 2, Trisociation 36
#
# Word 'Iceberg' is used 4 times across runs.
#  - In Run 1, Trisociation 81
#  - In Run 2, Trisociation 59
#  - In Run 2, Trisociation 88
#  - In Run 3, Trisociation 6
#
# Word 'Desert' is used 5 times across runs.
#  - In Run 1, Trisociation 82
#  - In Run 2, Trisociation 5
#  - In Run 2, Trisociation 39
#  - In Run 2, Trisociation 77
#  - In Run 3, Trisociation 5
#
# Word 'Mirage' is used 3 times across runs.
#  - In Run 1, Trisociation 82
#  - In Run 2, Trisociation 68
#  - In Run 2, Trisociation 96
#
# Word 'Sculpture' is used 3 times across runs.
#  - In Run 1, Trisociation 83
#  - In Run 2, Trisociation 29
#  - In Run 3, Trisociation 7
#
# Word 'Quill' is used 2 times across runs.
#  - In Run 1, Trisociation 86
#  - In Run 2, Trisociation 48
#
# Word 'Sea' is used 2 times across runs.
#  - In Run 1, Trisociation 87
#  - In Run 3, Trisociation 49
#
# Word 'Flame' is used 2 times across runs.
#  - In Run 1, Trisociation 88
#  - In Run 2, Trisociation 45
#
# Word 'Technology' is used 2 times across runs.
#  - In Run 1, Trisociation 89
#  - In Run 3, Trisociation 72
#
# Word 'Castle' is used 2 times across runs.
#  - In Run 1, Trisociation 95
#  - In Run 2, Trisociation 6
#
# Word 'Web' is used 3 times across runs.
#  - In Run 1, Trisociation 97
#  - In Run 3, Trisociation 78
#  - In Run 3, Trisociation 80
#
# Word 'Storm' is used 4 times across runs.
#  - In Run 1, Trisociation 98
#  - In Run 2, Trisociation 19
#  - In Run 3, Trisociation 73
#  - In Run 3, Trisociation 86
#
# Word 'Lightning' is used 2 times across runs.
#  - In Run 1, Trisociation 98
#  - In Run 2, Trisociation 32
#
# Word 'Violin' is used 2 times across runs.
#  - In Run 2, Trisociation 2
#  - In Run 3, Trisociation 2
#
# Word 'Galaxy' is used 2 times across runs.
#  - In Run 2, Trisociation 4
#  - In Run 3, Trisociation 2
#
# Word 'Quantum' is used 8 times across runs.
#  - In Run 2, Trisociation 6
#  - In Run 2, Trisociation 36
#  - In Run 2, Trisociation 56
#  - In Run 3, Trisociation 4
#  - In Run 3, Trisociation 19
#  - In Run 3, Trisociation 50
#  - In Run 3, Trisociation 65
#  - In Run 3, Trisociation 84
#
# Word 'Equation' is used 2 times across runs.
#  - In Run 2, Trisociation 7
#  - In Run 2, Trisociation 49
#
# Word 'Circuit' is used 3 times across runs.
#  - In Run 2, Trisociation 8
#  - In Run 2, Trisociation 46
#  - In Run 3, Trisociation 84
#
# Word 'Sonnet' is used 2 times across runs.
#  - In Run 2, Trisociation 9
#  - In Run 3, Trisociation 13
#
# Word 'Glacier' is used 4 times across runs.
#  - In Run 2, Trisociation 10
#  - In Run 2, Trisociation 66
#  - In Run 2, Trisociation 94
#  - In Run 3, Trisociation 10
#
# Word 'Perfume' is used 2 times across runs.
#  - In Run 2, Trisociation 10
#  - In Run 2, Trisociation 62
#
# Word 'Byte' is used 2 times across runs.
#  - In Run 2, Trisociation 10
#  - In Run 2, Trisociation 61
#
# Word 'Lion' is used 2 times across runs.
#  - In Run 2, Trisociation 11
#  - In Run 2, Trisociation 98
#
# Word 'Binary' is used 2 times across runs.
#  - In Run 2, Trisociation 11
#  - In Run 3, Trisociation 11
#
# Word 'Jazz' is used 3 times across runs.
#  - In Run 2, Trisociation 12
#  - In Run 3, Trisociation 9
#  - In Run 3, Trisociation 41
#
# Word 'Lace' is used 2 times across runs.
#  - In Run 2, Trisociation 14
#  - In Run 2, Trisociation 37
#
# Word 'Algorithm' is used 5 times across runs.
#  - In Run 2, Trisociation 14
#  - In Run 2, Trisociation 53
#  - In Run 3, Trisociation 1
#  - In Run 3, Trisociation 55
#  - In Run 3, Trisociation 74
#
# Word 'Avalanche' is used 2 times across runs.
#  - In Run 2, Trisociation 16
#  - In Run 3, Trisociation 91
#
# Word 'Pixel' is used 3 times across runs.
#  - In Run 2, Trisociation 16
#  - In Run 2, Trisociation 54
#  - In Run 3, Trisociation 10
#
# Word 'Symphony' is used 3 times across runs.
#  - In Run 2, Trisociation 17
#  - In Run 3, Trisociation 4
#  - In Run 3, Trisociation 52
#
# Word 'Cloud' is used 7 times across runs.
#  - In Run 2, Trisociation 21
#  - In Run 2, Trisociation 80
#  - In Run 3, Trisociation 30
#  - In Run 3, Trisociation 49
#  - In Run 3, Trisociation 66
#  - In Run 3, Trisociation 70
#  - In Run 3, Trisociation 81
#
# Word 'Comet' is used 2 times across runs.
#  - In Run 2, Trisociation 23
#  - In Run 2, Trisociation 70
#
# Word 'Aurora' is used 3 times across runs.
#  - In Run 2, Trisociation 24
#  - In Run 2, Trisociation 71
#  - In Run 3, Trisociation 14
#
# Word 'Logic' is used 2 times across runs.
#  - In Run 2, Trisociation 25
#  - In Run 3, Trisociation 47
#
# Word 'Code' is used 2 times across runs.
#  - In Run 2, Trisociation 26
#  - In Run 3, Trisociation 3
#
# Word 'Eclipse' is used 2 times across runs.
#  - In Run 2, Trisociation 27
#  - In Run 3, Trisociation 9
#
# Word 'Coral' is used 2 times across runs.
#  - In Run 2, Trisociation 28
#  - In Run 2, Trisociation 61
#
# Word 'Wheat' is used 3 times across runs.
#  - In Run 2, Trisociation 28
#  - In Run 2, Trisociation 46
#  - In Run 2, Trisociation 70
#
# Word 'Bamboo' is used 2 times across runs.
#  - In Run 2, Trisociation 29
#  - In Run 2, Trisociation 62
#
# Word 'Wolf' is used 2 times across runs.
#  - In Run 2, Trisociation 30
#  - In Run 2, Trisociation 68
#
# Word 'Network' is used 7 times across runs.
#  - In Run 2, Trisociation 30
#  - In Run 3, Trisociation 32
#  - In Run 3, Trisociation 64
#  - In Run 3, Trisociation 79
#  - In Run 3, Trisociation 82
#  - In Run 3, Trisociation 91
#  - In Run 3, Trisociation 100
#
# Word 'Cave' is used 4 times across runs.
#  - In Run 2, Trisociation 33
#  - In Run 2, Trisociation 69
#  - In Run 2, Trisociation 79
#  - In Run 3, Trisociation 40
#
# Word 'Framework' is used 2 times across runs.
#  - In Run 2, Trisociation 34
#  - In Run 2, Trisociation 52
#
# Word 'Lyric' is used 2 times across runs.
#  - In Run 2, Trisociation 35
#  - In Run 3, Trisociation 30
#
# Word 'Lava' is used 2 times across runs.
#  - In Run 2, Trisociation 37
#  - In Run 2, Trisociation 69
#
# Word 'Oasis' is used 4 times across runs.
#  - In Run 2, Trisociation 38
#  - In Run 2, Trisociation 77
#  - In Run 2, Trisociation 96
#  - In Run 3, Trisociation 23
#
# Word 'Tide' is used 2 times across runs.
#  - In Run 2, Trisociation 40
#  - In Run 2, Trisociation 91
#
# Word 'Protocol' is used 3 times across runs.
#  - In Run 2, Trisociation 40
#  - In Run 3, Trisociation 28
#  - In Run 3, Trisociation 77
#
# Word 'Silicon' is used 3 times across runs.
#  - In Run 2, Trisociation 42
#  - In Run 3, Trisociation 8
#  - In Run 3, Trisociation 86
#
# Word 'Seal' is used 2 times across runs.
#  - In Run 2, Trisociation 43
#  - In Run 2, Trisociation 94
#
# Word 'Jungle' is used 2 times across runs.
#  - In Run 2, Trisociation 44
#  - In Run 2, Trisociation 78
#
# Word 'Frost' is used 4 times across runs.
#  - In Run 2, Trisociation 44
#  - In Run 2, Trisociation 53
#  - In Run 2, Trisociation 73
#  - In Run 3, Trisociation 92
#
# Word 'Marsh' is used 2 times across runs.
#  - In Run 2, Trisociation 45
#  - In Run 3, Trisociation 22
#
# Word 'Stream' is used 4 times across runs.
#  - In Run 2, Trisociation 46
#  - In Run 2, Trisociation 51
#  - In Run 2, Trisociation 72
#  - In Run 3, Trisociation 45
#
# Word 'Reef' is used 3 times across runs.
#  - In Run 2, Trisociation 47
#  - In Run 2, Trisociation 91
#  - In Run 3, Trisociation 18
#
# Word 'Geyser' is used 2 times across runs.
#  - In Run 2, Trisociation 48
#  - In Run 2, Trisociation 90
#
# Word 'Array' is used 2 times across runs.
#  - In Run 2, Trisociation 48
#  - In Run 2, Trisociation 57
#
# Word 'Penguin' is used 2 times across runs.
#  - In Run 2, Trisociation 55
#  - In Run 2, Trisociation 88
#
# Word 'Interface' is used 4 times across runs.
#  - In Run 2, Trisociation 55
#  - In Run 3, Trisociation 29
#  - In Run 3, Trisociation 48
#  - In Run 3, Trisociation 63
#
# Word 'Canyon' is used 3 times across runs.
#  - In Run 2, Trisociation 56
#  - In Run 2, Trisociation 85
#  - In Run 3, Trisociation 12
#
# Word 'Snowstorm' is used 2 times across runs.
#  - In Run 2, Trisociation 57
#  - In Run 3, Trisociation 89
#
# Word 'Valley' is used 3 times across runs.
#  - In Run 2, Trisociation 58
#  - In Run 3, Trisociation 38
#  - In Run 3, Trisociation 86
#
# Word 'Socket' is used 2 times across runs.
#  - In Run 2, Trisociation 62
#  - In Run 3, Trisociation 99
#
# Word 'Tornado' is used 2 times across runs.
#  - In Run 2, Trisociation 64
#  - In Run 3, Trisociation 15
#
# Word 'Raindrop' is used 2 times across runs.
#  - In Run 2, Trisociation 65
#  - In Run 3, Trisociation 67
#
# Word 'Blizzard' is used 3 times across runs.
#  - In Run 2, Trisociation 67
#  - In Run 3, Trisociation 88
#  - In Run 3, Trisociation 99
#
# Word 'Gorge' is used 2 times across runs.
#  - In Run 2, Trisociation 74
#  - In Run 3, Trisociation 28
#
# Word 'Brook' is used 2 times across runs.
#  - In Run 2, Trisociation 75
#  - In Run 3, Trisociation 64
#
# Word 'Lake' is used 2 times across runs.
#  - In Run 2, Trisociation 76
#  - In Run 3, Trisociation 44
#
# Word 'Hash' is used 2 times across runs.
#  - In Run 2, Trisociation 77
#  - In Run 3, Trisociation 95
#
# Word 'Breeze' is used 2 times across runs.
#  - In Run 2, Trisociation 78
#  - In Run 3, Trisociation 80
#
# Word 'Dune' is used 2 times across runs.
#  - In Run 2, Trisociation 80
#  - In Run 3, Trisociation 37
#
# Word 'Delta' is used 2 times across runs.
#  - In Run 2, Trisociation 81
#  - In Run 3, Trisociation 25
#
# Word 'Prairie' is used 2 times across runs.
#  - In Run 2, Trisociation 84
#  - In Run 3, Trisociation 16
#
# Word 'Mist' is used 2 times across runs.
#  - In Run 2, Trisociation 84
#  - In Run 3, Trisociation 69
#
# Word 'Waterfall' is used 2 times across runs.
#  - In Run 2, Trisociation 87
#  - In Run 3, Trisociation 24
#
# Word 'Mesa' is used 2 times across runs.
#  - In Run 2, Trisociation 89
#  - In Run 3, Trisociation 26
#
# Word 'Fjord' is used 3 times across runs.
#  - In Run 2, Trisociation 92
#  - In Run 3, Trisociation 20
#  - In Run 3, Trisociation 56
#
# Word 'Plateau' is used 2 times across runs.
#  - In Run 2, Trisociation 93
#  - In Run 3, Trisociation 27
#
# Word 'Archipelago' is used 2 times across runs.
#  - In Run 2, Trisociation 95
#  - In Run 3, Trisociation 30
#
# Word 'Tundra' is used 2 times across runs.
#  - In Run 2, Trisociation 97
#  - In Run 3, Trisociation 35
#
# Word 'Savannah' is used 2 times across runs.
#  - In Run 2, Trisociation 98
#  - In Run 3, Trisociation 21
#
# Word 'Opera' is used 2 times across runs.
#  - In Run 3, Trisociation 11
#  - In Run 3, Trisociation 53
#
# Word 'Monsoon' is used 2 times across runs.
#  - In Run 3, Trisociation 13
#  - In Run 3, Trisociation 74
#
# Word 'Tempest' is used 2 times across runs.
#  - In Run 3, Trisociation 17
#  - In Run 3, Trisociation 87
#
# Word 'Virtual' is used 4 times across runs.
#  - In Run 3, Trisociation 18
#  - In Run 3, Trisociation 46
#  - In Run 3, Trisociation 69
#  - In Run 3, Trisociation 87
#
# Word 'Blockchain' is used 2 times across runs.
#  - In Run 3, Trisociation 22
#  - In Run 3, Trisociation 72
#
# Word 'Ballad' is used 2 times across runs.
#  - In Run 3, Trisociation 25
#  - In Run 3, Trisociation 54
#
# Word 'Augmented' is used 2 times across runs.
#  - In Run 3, Trisociation 25
#  - In Run 3, Trisociation 68
#
# Word 'Digital' is used 3 times across runs.
#  - In Run 3, Trisociation 26
#  - In Run 3, Trisociation 52
#  - In Run 3, Trisociation 90
#
# Word 'Encryption' is used 4 times across runs.
#  - In Run 3, Trisociation 33
#  - In Run 3, Trisociation 65
#  - In Run 3, Trisociation 74
#  - In Run 3, Trisociation 76
#
# Word 'Application' is used 2 times across runs.
#  - In Run 3, Trisociation 35
#  - In Run 3, Trisociation 98
#
# Word 'Data' is used 5 times across runs.
#  - In Run 3, Trisociation 40
#  - In Run 3, Trisociation 59
#  - In Run 3, Trisociation 61
#  - In Run 3, Trisociation 76
#  - In Run 3, Trisociation 89
#
# Word 'Software' is used 2 times across runs.
#  - In Run 3, Trisociation 42
#  - In Run 3, Trisociation 57
#
# Word 'Reality' is used 2 times across runs.
#  - In Run 3, Trisociation 46
#  - In Run 3, Trisociation 68
#
# Word 'Computing' is used 3 times across runs.
#  - In Run 3, Trisociation 49
#  - In Run 3, Trisociation 50
#  - In Run 3, Trisociation 97
#
# Word 'Machine' is used 2 times across runs.
#  - In Run 3, Trisociation 54
#  - In Run 3, Trisociation 69
#
# Word 'Internet' is used 4 times across runs.
#  - In Run 3, Trisociation 60
#  - In Run 3, Trisociation 77
#  - In Run 3, Trisociation 94
#  - In Run 3, Trisociation 96
#
# Word 'Deep' is used 2 times across runs.
#  - In Run 3, Trisociation 62
#  - In Run 3, Trisociation 80
#
# Word 'User' is used 2 times across runs.
#  - In Run 3, Trisociation 63
#  - In Run 3, Trisociation 85
#
# Word 'Peer-to-Peer' is used 2 times across runs.
#  - In Run 3, Trisociation 71
#  - In Run 3, Trisociation 91
#
# Word 'Distributed' is used 2 times across runs.
#  - In Run 3, Trisociation 73
#  - In Run 3, Trisociation 97
#
# Word 'Layer' is used 3 times across runs.
#  - In Run 3, Trisociation 82
#  - In Run 3, Trisociation 98
#  - In Run 3, Trisociation 99

# %%
# task 1 : display the duplicates in a nicer visual
# task 2 : can the duplicates code handle all the prompt type returns
# task 3 : do the mega trisociation prompt and see if any real difference along with language
# task 4 : do cosine similarity
# task 5 : display the base run data in a nicer format
# task 6 : what about a word cloud?

# %%
# trisociation prompt

TRISOCIATION_PROMPT=f"""

---

**Strict Exclusion List**
_Before embarking on the task, it is imperative to note that the following words are strictly prohibited from use in the trisociations:_

- Hiraeth
- Zephyr
- Ubuntu
- Petrichor
- Yugen
- Saudade
- Komorebi
- Tsundoku
- Cwtch
- Wabi-Sabi
- Mamihlapinatapai
- Fernweh
- Flaneur
- Hygge
- Mangata
- Samadhi
- Apricity

---

**Guidelines for Diverse and Unique Trisociations:**
As an advanced algorithm with access to a vast vector database of semantic embeddings, your role is to facilitate the trisociation process — a creative endeavor that interlaces three semantically distant concepts. Your mission is to construct trisociations that are linguistically diverse and conceptually distinctive, avoiding commonly used words and uncovering hidden linguistic gems.

---

_Please ensure that none of the words in the strict exclusion list are used in the trisociations._

1. **Explore the Uncommon**: Avoid frequently chosen words and seek out less common vocabulary.
2. **Prioritize Lesser-Known Vocabulary**: Focus on words that are less commonly used in creative writing, poetry, and literary contexts, aiming to uncover unique and underrepresented words.
3. **Thematic Diversity**: Incorporate words from themes like technology, mythology, professions, emotions, and weather phenomena, avoiding the obvious choices.
4. **Historical and Cultural Significance**: Choose words with historical or cultural resonance, especially those that are less known or underrepresented.
5. **Vibrant Language Use**: Include regional dialects or slang, with a focus on those that are less frequently used.
6. **Varied Parts of Speech**: Mix nouns, verbs, adjectives, and adverbs, especially those that are less common in trisociation contexts.
7. **Sensory Exploration**: Select sensory words that are vivid yet not the usual go-to options.
8. **Abstract and Tangible Fusion**: Blend abstract concepts with concrete items in unconventional ways.
9. **Language Family Diversity**: Draw from a wide array of language families, especially focusing on those less represented in common discourse.
10. **Creative Figurative Language**: Use metaphors, similes, and symbolic language, avoiding clichés and common expressions.
11. **Wide Emotional Range**: Cover a spectrum of emotions with less typical word choices.
12. **Temporal and Cultural Fusion**: Connect different eras and cultures, going beyond well-trodden paths.
13. **Lesser-Known Language Exploration**: Seek out words from lesser-known languages and dialects.
14. **Balanced Elements**: Ensure that each word contributes equally to the trisociation, without any overshadowing the others.
15. **Semantic Uniqueness**: Ensure that each trisociation stands out in its conceptual composition, distinct from typical combinations.
16. **Language Identification**: In each trisociation, identify the languages of the chosen words. This highlights the linguistic diversity and encourages the exploration of a variety of languages, including lesser-known ones.

---

Task:

Generate {n} Trisociations adhering to the above guidelines. Each trisociation should be a creative blend of three semantically distant nouns, showcasing linguistic innovation and conceptual uniqueness. 
The words in the exclusion list should not be part of any trisociation. No additional comments, explanations or elaborations beyond the trisociation itself.

Output Format :

1. Word (language) - Word (language) - Word (language)
2. Word (language) - Word (language) - Word (language)
...

"""
