# %%
# imports

from pathlib import Path
from openai import OpenAI
from dotenv import load_dotenv
import os
import random
import time
import itertools
import pandas as pd
from collections import defaultdict
import re

# %%
# load API key

dotenv_path = Path(r"C:\Storage\python_projects\ashvin\.env")
load_dotenv(dotenv_path=dotenv_path)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
# main constants

GPT_MODEL_TEXT_ALIAS = "gpt-4-turbo-preview"
GPT_MODEL_VISION_ALIAS = "gpt-4-vision-preview"

# additional constants as at 31/01/24
GPT_MODEL_TEXT = "gpt-4-0125-preview"
IMAGE_MODEL = "dall-e-3"
EMBEDDINGS_MODEL = "text-moderation-latest"

# %%
# variations
n = 300
runs = 3

# %%
# simple prompt
base_prompt = f"""
Generate {n} trisociations as a list.
"""

instruction_prompt = f"""
Generate {n} trisociations as a list. No additional comments or elaborations.
"""
format_prompt = f"""
Generate {n} trisociations in the format below. No additional comments or elaborations.
1. Word - Word - Word
2. Word - Word - Word
...
"""
language_prompt = f"""
Generate {n} trisociations in the format below. No additional comments or elaborations.
1. Word (language) - Word (language) - Word (language)
2. Word (language) - Word (language) - Word (language)
...
"""
unique_prompt = f"""
Generate {n} trisociations in the format below. No additional comments or elaborations. Make each word unique.
1. Word - Word - Word
2. Word - Word - Word
...
"""
avoid_prompt = f"""
Generate {n} trisociations in the format below. No additional comments or elaborations. avoid duplicate words within and across trisociations.
1. Word - Word - Word
2. Word - Word - Word
...
"""

# %%
#instantiate client
client = OpenAI()

# %%
final_prompt = avoid_prompt

# %%
# Function to perform a single run and collect data
def perform_run(prompt_text):
    start_time = time.time()
    completion = client.chat.completions.create(
        model=GPT_MODEL_TEXT_ALIAS,
        messages=[
            {"role": "system", "content": prompt_text},
        ]
    )
    end_time = time.time()
    
    trisociation_answer = completion.choices[0].message.content
    execution_time = end_time - start_time
    prompt_tokens = completion.usage.prompt_tokens
    completion_tokens = completion.usage.completion_tokens
    total_tokens = completion.usage.total_tokens

    return {
        'execution_time': execution_time,
        'prompt_tokens': prompt_tokens,
        'completion_tokens': completion_tokens,
        'total_tokens': total_tokens,
        'trisociations': trisociation_answer
    }

# %%
# List to store results from all runs
results = []

# Perform multiple runs
for _ in range(runs):
    result = perform_run(final_prompt)
    results.append(result)

# Calculate average metrics
avg_execution_time = sum(r['execution_time'] for r in results) / runs
avg_prompt_tokens = sum(r['prompt_tokens'] for r in results) / runs
avg_completion_tokens = sum(r['completion_tokens'] for r in results) / runs
avg_total_tokens = sum(r['total_tokens'] for r in results) / runs

# Print out the results
print(f"Average execution time: {avg_execution_time:.2f} seconds")
print(f"Average prompt tokens: {avg_prompt_tokens:.2f}")
print(f"Average completion tokens: {avg_completion_tokens:.2f}")
print(f"Average total tokens: {avg_total_tokens:.2f}")

# Additionally, print each run's trisociations
for i, r in enumerate(results, 1):
    print(f"Run {i} trisociations:\n{r['trisociations']}\n")
# Out:
# Average execution time: 167.88 seconds
# Average prompt tokens: 55.00
# Average completion tokens: 3063.00
# Average total tokens: 3118.00
# Run 1 trisociations:
# 1. Mountain - River - Valley
# 2. Chocolate - Vanilla - Strawberry
# 3. Sun - Moon - Stars
# 4. Winter - Spring - Summer
# 5. Pencil - Pen - Marker
# 6. Lion - Tiger - Bear
# 7. Bread - Cheese - Wine
# 8. Triangle - Square - Circle
# 9. Gold - Silver - Bronze
# 10. Rain - Snow - Hail
# 11. Book - Magazine - Newspaper
# 12. Apple - Banana - Cherry
# 13. Table - Chair - Sofa
# 14. Guitar - Piano - Violin
# 15. Red - Blue - Yellow
# 16. Hat - Scarf - Gloves
# 17. Coffee - Tea - Milk
# 18. Car - Bicycle - Train
# 19. Clock - Watch - Calendar
# 20. Toothbrush - Toothpaste - Floss
# 21. Fork - Knife - Spoon
# 22. Ocean - Sea - Lake
# 23. Eagle - Falcon - Hawk
# 24. Rose - Tulip - Daisy
# 25. Painting - Sculpture - Drawing
# 26. Duck - Goose - Swan
# 27. Onion - Garlic - Ginger
# 28. Candle - Lamp - Flashlight
# 29. Cricket - Football - Basketball
# 30. Cowboy - Knight - Pirate
# 31. Bee - Butterfly - Ant
# 32. Sand - Dirt - Clay
# 33. Mouse - Keyboard - Screen
# 34. Hammer - Screwdriver - Wrench
# 35. Porridge - Soup - Stew
# 36. Africa - Asia - Europe
# 37. Laugh - Cry - Smile
# 38. Window - Door - Roof
# 39. Tower - Castle - Palace
# 40. Ink - Paint - Dye
# 41. Wheat - Corn - Rice
# 42. Doctor - Nurse - Surgeon
# 43. Sunflower - Lavender - Jasmine
# 44. Eagle - Dove - Peacock
# 45. Ice - Water - Vapor
# 46. Heart - Brain - Lung
# 47. Fish - Shrimp - Crab
# 48. Mango - Peach - Plum
# 49. Sugar - Salt - Pepper
# 50. Kite - Balloon - Parachute
# 51. Owl - Bat - Moth
# 52. Shark - Dolphin - Whale
# 53. Drum - Flute - Trumpet
# 54. Fox - Wolf - Coyote
# 55. Storm - Thunder - Lightning
# 56. Pasta - Pizza - Risotto
# 57. Elephant - Rhino - Hippo
# 58. Medal - Trophy - Ribbon
# 59. Key - Lock - Chain
# 60. Island - Peninsula - Continent
# 61. Rocket - Spaceship - Satellite
# 62. Ring - Necklace - Bracelet
# 63. Zebra - Giraffe - Elephant
# 64. Quiz - Exam - Test
# 65. Diary - Journal - Notebook
# 66. Peach - Nectarine - Apricot
# 67. Frog - Toad - Newt
# 68. Cucumber - Zucchini - Squash
# 69. Cactus - Fern - Palm
# 70. Clown - Magician - Juggler
# 71. Violin - Viola - Cello
# 72. Blanket - Pillow - Mattress
# 73. Hurricane - Tornado - Cyclone
# 74. Camel - Llama - Alpaca
# 75. Butter - Margarine - Mayonnaise
# 76. Earthquake - Volcano - Tsunami
# 77. Comet - Meteor - Asteroid
# 78. Lemonade - Iced Tea - Soda
# 79. Monsoon - Drought - Flood
# 80. Crow - Raven - Magpie
# 81. Sage - Mint - Basil
# 82. Acorn - Pinecone - Maple Seed
# 83. Panda - Koala - Polar Bear
# 84. Grapes - Raisins - Wine
# 85. Sponge - Brush - Broom
# 86. Horse - Donkey - Mule
# 87. Diamond - Ruby - Sapphire
# 88. Harp - Lute - Mandolin
# 89. Tarantula - Scorpion - Centipede
# 90. Crocodile - Alligator - Gharial
# 91. Hammer - Anvil - Forge
# 92. Shampoo - Conditioner - Soap
# 93. Tulip - Poppy - Lotus
# 94. Ray - Shark - Eel
# 95. Bead - Button - Buckle
# 96. Mustard - Ketchup - Mayo
# 97. Pear - Fig - Date
# 98. Nutmeg - Cinnamon - Clove
# 99. Scissors - Clippers - Shears
# 100. Jacket - Coat - Sweater
# 101. Kiwi - Lime - Lemon
# 102. Walnut - Almond - Pecan
# 103. Lily - Orchid - Hibiscus
# 104. Chili - Pepper - Paprika
# 105. Moth - Caterpillar - Butterfly
# 106. Hamburger - Sandwich - Hotdog
# 107. Cranberry - Blueberry - Raspberry
# 108. Beetle - Dragonfly - Firefly
# 109. Caterpillar - Worm - Slug
# 110. Skirt - Dress - Gown
# 111. Birch - Oak - Maple
# 112. Chalk - Pencil - Crayon
# 113. Daffodil - Bluebell - Snowdrop
# 114. Olive - Pickle - Jalapeño
# 115. Sparrow - Finch - Canary
# 116. Squirrel - Chipmunk - Rabbit
# 117. Acoustic - Electric - Bass
# 118. UFO - Rocket - Satellite
# 119. Mail - Parcel - Letter
# 120. Smoke - Fog - Mist
# 121. Leaf - Branch - Root
# 122. Hippo - Crocodile - Elephant
# 123. Chisel - Saw - Drill
# 124. Mint - Gum - Candy
# 125. Sunscreen - Hat - Sunglasses
# 126. Rainbow - Aurora - Mirage
# 127. Museum - Gallery - Library
# 128. Stamp - Coin - Ticket
# 129. Whale - Dolphin - Seal
# 130. Coral - Shell - Starfish
# 131. Calf - Foal - Lamb
# 132. Puddle - Pond - Pool
# 133. Cinnamon - Ginger - Nutmeg
# 134. Joker - King - Queen
# 135. Pickle - Relish - Sauerkraut
# 136. Pyramid - Sphere - Cube
# 137. Thunder - Rain - Fog
# 138. Canvas - Paper - Wood
# 139. Lake - River - Stream
# 140. Biscuit - Cookie - Cake
# 141. Marble - Quartz - Granite
# 142. Compass - Map - GPS
# 143. Heron - Crane - Stork
# 144. Hawk - Eagle - Falcon
# 145. Tunnel - Bridge - Road
# 146. Omelette - Scrambled - Boiled
# 147. Cherry - Berry - Currant
# 148. Lime - Lemon - Orange
# 149. Deck - Patio - Porch
# 150. Ocean - Gulf - Bay
# 151. Albatross - Seagull - Pelican
# 152. Bungalow - Cottage - Villa
# 153. Ale - Lager - Stout
# 154. Axe - Hatchet - Cleaver
# 155. Banana - Plantain - Mango
# 156. Barley - Oats - Rye
# 157. Basil - Thyme - Oregano
# 158. Glue - Tape - Adhesive
# 159. Broom - Mop - Vacuum
# 160. Butterfly - Moth - Caterpillar
# 161. Canary - Parrot - Sparrow
# 162. Candelabra - Lantern - Torch
# 163. Canyon - Gorge - Ravine
# 164. Carousel - Ferris Wheel - Rollercoaster
# 165. Cartwheel - Somersault - Flip
# 166. Cathedral - Chapel - Church
# 167. Cheetah - Leopard - Jaguar
# 168. Cherry - Apricot - Peach
# 169. Chestnut - Hazelnut - Almond
# 170. Chimney - Stove - Furnace
# 171. Circus - Carnival - Festival
# 172. Citrus - Berry - Melon
# 173. Cliff - Hill - Mountain
# 174. Cloak - Cape - Shawl
# 175. Clover - Fern - Ivy
# 176. Coal - Charcoal - Briquette
# 177. Cobweb - Spiderweb - Net
# 178. Cocoon - Chrysalis - Egg
# 179. Comet - Asteroid - Meteor
# 180. Compass - Sextant - Astrolabe
# 181. Coral - Anemone - Barnacle
# 182. Cottage - Cabin - Shack
# 183. Coyote - Fox - Wolf
# 184. Crane - Forklift - Hoist
# 185. Crayfish - Lobster - Shrimp
# 186. Creek - Brook - Stream
# 187. Crowley - Hatchet - Saw
# 188. Crystal - Gemstone - Jewel
# 189. Cube - Sphere - Pyramid
# 190. Cuckoo - Sparrow - Parrot
# 191. Daffodil - Tulip - Rose
# 192. Dandelion - Buttercup - Clover
# 193. Date - Fig - Prune
# 194. Deer - Moose - Elk
# 195. Desert - Oasis - Dune
# 196. Dew - Fog - Mist
# 197. Diamond - Sapphire - Emerald
# 198. Diary - Calendar - Planner
# 199. Dime - Nickel - Quarter
# 200. Dinghy - Yacht - Sailboat
# 201. Disco - Jazz - Opera
# 202. Dodo - Pigeon - Sparrow
# 203. Dogwood - Willow - Maple
# 204. Dolphin - Porpoise - Whale
# 205. Domino - Dice - Poker
# 206. Donut - Muffin - Bagel
# 207. Dove - Pigeon - Sparrow
# 208. Dragon - Griffin - Unicorn
# 209. Drizzle - Shower - Downpour
# 210. Duckling - Gosling - Cygnet
# 211. Dune - Hill - Mountain
# 212. Earring - Necklace - Bracelet
# 213. Easel - Canvas - Palette
# 214. Ebony - Mahogany - Oak
# 215. Eclipse - Equinox - Solstice
# 216. Eel - Snake - Worm
# 217. Eggplant - Zucchini - Cucumber
# 218. Elk - Caribou - Moose
# 219. Elm - Birch - Willow
# 220. Emerald - Jade - Peridot
# 221. Empire - Kingdom - Duchy
# 222. Envelope - Postcard - Stamp
# 223. Espresso - Latte - Cappuccino
# 224. Fable - Myth - Legend
# 225. Falcon - Hawk - Eagle
# 226. Fan - Air Conditioner - Cooler
# 227. Fern - Moss - Algae
# 228. Fiddle - Banjo - Ukulele
# 229. Fig - Date - Prune
# 230. Finch - Sparrow - Robin
# 231. Firefly - Moth - Glowworm
# 232. Flamingo - Pelican - Stork
# 233. Flare - Beacon - Torch
# 234. Flask - Bottle - Canteen
# 235. Flea - Tick - Louse
# 236. Fleece - Wool - Cashmere
# 237. Flock - Herd - Swarm
# 238. Flounder - Halibut - Sole
# 239. Foam - Sponge - Bubble
# 240. Fog - Mist - Haze
# 241. Footprint - Fingerprint - Shadow
# 242. Forest - Jungle - Woodland
# 243. Fountain - Geyser - Spring
# 244. Foxglove - Snapdragon - Daisy
# 245. Freeway - Highway - Avenue
# 246. Fresco - Mural - Graffiti
# 247. Fridge - Freezer - Cooler
# 248. Frigate - Destroyer - Submarine
# 249. Frost - Ice - Snow
# 250. Frown - Scowl - Grimace
# 251. Galaxy - Nebula - Universe
# 252. Gale - Breeze - Wind
# 253. Gallery - Museum - Exhibition
# 254. Garlic - Onion - Chive
# 255. Garnet - Amethyst - Aquamarine
# 256. Gecko - Lizard - Salamander
# 257. Gem - Jewel - Crystal
# 258. Gerbil - Hamster - Guinea Pig
# 259. Geyser - Spring - Fountain
# 260. Gherkin - Pickle - Olive
# 261. Gingham - Plaid - Tartan
# 262. Glacier - Iceberg - Ice Shelf
# 263. Glade - Meadow - Clearing
# 264. Goblet - Chalice - Cup
# 265. Goldfish - Koi - Carp
# 266. Gondola - Canoe - Kayak
# 267. Goose - Duck - Swan
# 268. Gorilla - Chimpanzee - Orangutan
# 269. Gown - Dress - Robe
# 270. Grackle - Starling - Blackbird
# 271. Grain - Wheat - Barley
# 272. Granite - Quartz - Marble
# 273. Graphite - Lead - Carbon
# 274. Grasshopper - Cricket - Locust
# 275. Gravel - Sand - Pebble
# 276. Greenhouse - Conservatory - Nursery
# 277. Grid - Matrix - Network
# 278. Griddle - Pan - Skillet
# 279. Grill - Barbecue - Smoker
# 280. Grotto - Cave - Cavern
# 281. Grove - Orchard - Vineyard
# 282. Gull - Albatross - Pelican
# 283. Guppy - Tetra - Goldfish
# 284. Gurgle - Bubble - Splash
# 285. Gymnasium - Arena - Stadium
# 286. Hacienda - Villa - Manor
# 287. Hail - Sleet - Snow
# 288. Halo - Aura - Glow
# 289. Hamlet - Village - Town
# 290. Hammer - Mallet - Gavel
# 291. Handbag - Purse - Wallet
# 292. Hangar - Garage - Shed
# 293. Harbor - Port - Dock
# 294. Hare - Rabbit - Bunny
# 295. Harpoon - Spear - Lance
# 296. Harpsichord - Piano - Organ
# 297. Harvest - Reap - Gather
# 298. Hatchet - Axe - Cleaver
# 299. Hawk - Falcon - Kestrel
# 300. Haystack - Barn - Silo
#
# Run 2 trisociations:
# 1. Apple - Moon - Whisper
# 2. Ocean - Candle - Library
# 3. Rainforest - Typewriter - Saturn
# 4. Python - Snowflake - Museum
# 5. Vertex - Horizon - Lighthouse
# 6. Paradox - Oasis - Chalk
# 7. Glacier - Violin - Algorithm
# 8. Riddle - Cosmos - Sunflower
# 9. Avalanche - Piano - Nebula
# 10. Thunder - Castle - Papyrus
# 11. Mirage - Tulip - Quantum
# 12. Coral - Lantern - Theory
# 13. Meadow - Sphinx - Pixel
# 14. Vortex - Maple - Symphony
# 15. Cliff - Compass - Sonnet
# 16. Prism - Wolf - Archive
# 17. Aurora - Silk - Equation
# 18. Eclipse - Falcon - Opera
# 19. Gargoyle - Lotus - Catalyst
# 20. Infinity - Peacock - Scroll
# 21. Zephyr - Oak - Mosaic
# 22. Orchard - Galaxy - Harp
# 23. Tide - Pyramid - Manuscript
# 24. Phoenix - Daisy - Matrix
# 25. Blizzard - Guitar - Constellation
# 26. Monsoon - Sapphire - Lyric
# 27. Serenade - Volcano - Labyrinth
# 28. Dew - Cedar - Cipher
# 29. Breeze - Lion - Tablet
# 30. Mirage - Raven - Renaissance
# 31. Summit - Iris - Odyssey
# 32. Canyon - Flute - Chronicle
# 33. Tornado - Rose - Codex
# 34. Mist - Elm - Allegory
# 35. Cascade - Orchid - Formula
# 36. Pinnacle - Anvil - Fable
# 37. Tsunami - Cobalt - Anthem
# 38. Geyser - Fox - Parable
# 39. Plateau - Jasmine - Ballad
# 40. Oasis - Eagle - Epic
# 41. Aurora - Cherry - Graph
# 42. Tundra - Onyx - Saga
# 43. Archipelago - Amethyst - Cantata
# 44. Glacier - Lynx - Prose
# 45. Flora - Dome - Novella
# 46. Cyclone - Maple - Stanza
# 47. Terrain - Basil - Dialogue
# 48. Fjord - Lavender - Soliloquy
# 49. Peninsula - Sage - Ballade
# 50. Delta - Magnolia - Couplet
# 51. Prairie - Obsidian - Exposition
# 52. Taiga - Hyacinth - Script
# 53. Plateau - Falcon - Monologue
# 54. Canyon - Heather - Quatrain
# 55. Crater - Falcon - Narrative
# 56. Savanna - Willow - Sonnet
# 57. Foothill - Granite - Prologue
# 58. Dune - Lotus - Verses
# 59. Moor - Topaz - Chronicle
# 60. Estuary - Pine - Acrostic
# 61. Shoal - Geranium - Haiku
# 62. Marsh - Elm - Sestina
# 63. Stream - Ruby - Ode
# 64. Gulch - Zinnia - Villanelle
# 65. Crevasse - Quartz - Elegy
# 66. Ravine - Poppy - Ghazal
# 67. Butte - Cedar - Limerick
# 68. Knoll - Olive - Free Verse
# 69. Mesa - Basil - Cinquain
# 70. Valley - Sage - Lyricism
# 71. Summit - Pansy - Palindrome
# 72. Ridge - Hemlock - Pantoum
# 73. Highland - Agate - Pastoral
# 74. Lowland - Birch - Sonnet
# 75. Plateau - Daffodil - Epicurean
# 76. Basin - Snapdragon - Alexandrine
# 77. Watershed - Thyme - Epigram
# 78. Tributary - Marigold - Quatorzain
# 79. Lagoon - Nutmeg - Madrigal
# 80. Bayou - Petunia - Rondeau
# 81. Bog - Fern - Shanty
# 82. Fen - Tarragon - Sermon
# 83. Swamp - Myrtle - Didactic
# 84. Pond - Coriander - Enjambment
# 85. Lake - Lilac - Anecdote
# 86. Reservoir - Verbena - Allegory
# 87. River - Sorrel - Epitaph
# 88. Creek - Jasmine - Narrative
# 89. Brook - Gardenia - Eulogy
# 90. Streamlet - Linden - Epic
# 91. Rivulet - Marjoram - Canticle
# 92. Gully - Heather - Sketch
# 93. Runnel - Violet - Memoir
# 94. Channel - Daisy - Soliloquy
# 95. Strait - Chrysanthemum - Discourse
# 96. Firth - Beryl - Chronicle
# 97. Estuary - Clover - Saga
# 98. Delta - Hawthorn - Aria
# 99. Fjord - Lavender - Thesis
# 100. Gulch - Flax - Dialogue
# 101. Ravine - Orchid - Monologue
# 102. Gorge - Peony - Rhapsody
# 103. Canyon - Chamomile - Prologue
# 104. Trench - Gardenia - Treatise
# 105. Valley - Juniper - Narrative
# 106. Dale - Rosemary - Exegesis
# 107. Basin - Tansy - Biography
# 108. Plateau - Sagebrush - Fiction
# 109. Mesa - Snapdragon - Non-fiction
# 110. Plain - Dandelion - Fantasy
# 111. Prairie - Thistle - Memoir
# 112. Steppe - Primrose - Adventure
# 113. Tundra - Begonia - Sci-fi
# 114. Dune - Yarrow - Mystery
# 115. Desert - Lamium - Thriller
# 116. Mountain - Lavender - Drama
# 117. Hill - Moss - Comedy
# 118. Cliff - Ivy - Romance
# 119. Peak - Aspen - Satire
# 120. Ridge - Birch - Poetry
# 121. Escarpment - Cedar - Prose
# 122. Plateau - Dogwood - Documentary
# 123. Mesa - Almond - Animation
# 124. Terrace - Cherry - Art
# 125. Slope - Olive - Music
# 126. Bank - Willow - Dance
# 127. Coast - Magnolia - Theatre
# 128. Shore - Hazel - Cinema
# 129. Beach - Holly - Broadcasting
# 130. Sand - Jasmine - Journalism
# 131. Gravel - Lilac - Telecommunication
# 132. Stone - Maple - Advertising
# 133. Pebble - Narcissus - Networking
# 134. Boulder - Oak - Technology
# 135. Cliff - Ash - Engineering
# 136. Crag - Beech - Astronomy
# 137. Overhang - Cedar - Botany
# 138. Precipice - Daisy - Chemistry
# 139. Ridge - Elm - Computing
# 140. Summit - Fir - Ecology
# 141. Top - Garnet - Geography
# 142. Apex - Heather - Geology
# 143. Pinnacle - Iris - Immunology
# 144. Peak - Jade - Mathematics
# 145. Crest - Kelp - Medicine
# 146. Hilltop - Lavender - Microbiology
# 147. Mountaintop - Moss - Neuroscience
# 148. Plateau - Nutmeg - Oceanography
# 149. Mesa - Opal - Physics
# 150. Terrace - Pine - Psychology
# 151. Slope - Quartz - Sociology
# 152. Bank - Rose - Zoology
# 153. Coast - Sage - Archaeology
# 154. Shore - Thyme - Anthropology
# 155. Beach - Umbrella - Linguistics
# 156. Sand - Vanilla - Philosophy
# 157. Gravel - Willow - Political Science
# 158. Stone - Xylophone - Public Administration
# 159. Pebble - Yellow - Religious Studies
# 160. Boulder - Zebra - Visual Arts
# 161. Cliff - Azalea - Performing Arts
# 162. Crag - Bamboo - Musicology
# 163. Overhang - Carnation - Theatre Studies
# 164. Precipice - Daffodil - Film Studies
# 165. Ridge - Eucalyptus - Media Studies
# 166. Summit - Fig - Cultural Studies
# 167. Top - Geranium - Environmental Science
# 168. Apex - Hibiscus - Information Science
# 169. Pinnacle - Icicle - Social Work
# 170. Peak - Jasmine - Education
# 171. Crest - Kiwi - Business
# 172. Hilltop - Lemon - Economics
# 173. Mountaintop - Mango - Aeronautics
# 174. Plateau - Nectarine - Robotics
# 175. Mesa - Olive - Nanotechnology
# 176. Terrace - Peach - Cybersecurity
# 177. Slope - Quince - Data Science
# 178. Bank - Raspberry - Artificial Intelligence
# 179. Coast - Strawberry - Environmental Engineering
# 180. Shore - Tangerine - Marine Biology
# 181. Beach - Ugli Fruit - Conservation Biology
# 182. Sand - Vanilla - Renewable Energy
# 183. Gravel - Watermelon - Urban Planning
# 184. Stone - Xigua - Public Health
# 185. Pebble - Yucca - Nursing
# 186. Boulder - Zinnia - Pharmacy
# 187. Cliff - Alder - Veterinary
# 188. Crag - Birch - Dentistry
# 189. Overhang - Cedar - Nutrition
# 190. Precipice - Dogwood - Physiotherapy
# 191. Ridge - Elm - Occupational Therapy
# 192. Summit - Fir - Speech Therapy
# 193. Top - Ginkgo - Psychiatry
# 194. Apex - Hawthorn - Orthopedic
# 195. Pinnacle - Ivy - Oncology
# 196. Peak - Jasmine - Neurology
# 197. Crest - Kudzu - Cardiology
# 198. Hilltop - Lilac - Gastroenterology
# 199. Mountaintop - Maple - Dermatology
# 200. Plateau - Nettle - Rheumatology
# 201. Mesa - Oak - Endocrinology
# 202. Terrace - Pine - Ophthalmology
# 203. Slope - Quince - Audiology
# 204. Bank - Rose - Podiatry
# 205. Coast - Sage - Gerontology
# 206. Shore - Tulip - Pediatrics
# 207. Beach - Umbrella - Obstetrics
# 208. Sand - Violet - Gynecology
# 209. Gravel - Willow - Immunotherapy
# 210. Stone - Xylosma - Pathology
# 211. Pebble - Yucca - Virology
# 212. Boulder - Zephyr - Hematology
# 213. Cliff - Amaranth - Mycology
# 214. Crag - Birch - Parasitology
# 215. Overhang - Cedar - Entomology
# 216. Precipice - Dogwood - Herpetology
# 217. Ridge - Elm - Ichthyology
# 218. Summit - Fir - Ornithology
# 219. Top - Gorse - Mammalogy
# 220. Apex - Heather - Primatology
# 221. Pinnacle - Ivy - Ethology
# 222. Peak - Juniper - Paleontology
# 223. Crest - Kelp - Petrology
# 224. Hilltop - Lilac - Sedimentology
# 225. Mountaintop - Magnolia - Vulcanology
# 226. Plateau - Nettle - Seismology
# 227. Mesa - Oak - Meteorology
# 228. Terrace - Pine - Climatology
# 229. Slope - Quince - Hydrology
# 230. Bank - Rose - Oceanography
# 231. Coast - Sage - Glaciology
# 232. Shore - Thistle - Biogeography
# 233. Beach - Umbrella - Soil Science
# 234. Sand - Violet - Geomorphology
# 235. Gravel - Willow - Cartography
# 236. Stone - Xerophyte - Remote Sensing
# 237. Pebble - Yarrow - Geographic Information Systems
# 238. Boulder - Zinnia - Urban Geography
# 239. Cliff - Azurite - Cultural Geography
# 240. Crag - Bamboo - Historical Geography
# 241. Overhang - Carnation - Biostatistics
# 242. Precipice - Daffodil - Epidemiology
# 243. Ridge - Elderberry - Public Policy
# 244. Summit - Fig - Environmental Policy
# 245. Top - Grape - Urban Studies
# 246. Apex - Hibiscus - Rural Studies
# 247. Pinnacle - Iris - Development Studies
# 248. Peak - Jasmine - International Relations
# 249. Crest - Kiwi - Political Economy
# 250. Hilltop - Lemon - Sociology of Law
# 251. Mountaintop - Mango - Criminology
# 252. Plateau - Nectarine - Ethnic Studies
# 253. Mesa - Olive - Gender Studies
# 254. Terrace - Peach - Disability Studies
# 255. Slope - Quince - Ageing Studies
# 256. Bank - Raspberry - Youth Studies
# 257. Coast - Strawberry - Leisure Studies
# 258. Shore - Tangerine - Tourism Studies
# 259. Beach - Ugli Fruit - Hospitality Management
# 260. Sand - Vanilla - Event Management
# 261. Gravel - Watermelon - Sport Management
# 262. Stone - Xigua - Education Management
# 263. Pebble - Yucca - Health Management
# 264. Boulder - Zinnia - Social Entrepreneurship
# 265. Cliff - Alder - Non-profit Management
# 266. Crag - Birch - Human Resource Management
# 267. Overhang - Cedar - Organizational Behavior
# 268. Precipice - Dogwood - Organizational Theory
# 269. Ridge - Elm - Business Ethics
# 270. Summit - Fir - Corporate Governance
# 271. Top - Ginkgo - Marketing
# 272. Apex - Hawthorn - Advertising
# 273. Pinnacle - Ivy - Brand Management
# 274. Peak - Jasmine - Sales Management
# 275. Crest - Kudzu - Market Research
# 276. Hilltop - Lilac - Consumer Behavior
# 277. Mountaintop - Maple - Product Management
# 278. Plateau - Nettle - Project Management
# 279. Mesa - Oak - Operations Management
# 280. Terrace - Pine - Supply Chain Management
# 281. Slope - Quince - Logistics
# 282. Bank - Rose - Quality Management
# 283. Coast - Sage - Risk Management
# 284. Shore - Tulip - Financial Management
# 285. Beach - Umbrella - Asset Management
# 286. Sand - Violet - Investment Analysis
# 287. Gravel - Willow - Corporate Finance
# 288. Stone - Xylosma - Accounting
# 289. Pebble - Yucca - Auditing
# 290. Boulder - Zephyr - Taxation
# 291. Cliff - Amaranth - International Business
# 292. Crag - Birch - Entrepreneurship
# 293. Overhang - Cedar - Innovation Management
# 294. Precipice - Dogwood - Environmental Management
# 295. Ridge - Elm - Energy Management
# 296. Summit - Fir - Real Estate
# 297. Top - Gorse - Urban Design
# 298. Apex - Heather - Landscape Architecture
# 299. Pinnacle - Ivy - Interior Design
# 300. Peak - Juniper - Fashion Design
#
# Run 3 trisociations:
# 1. Giraffe - Latte - Asteroid
# 2. Thunder - Encyclopedia - Marshmallow
# 3. Skyscraper - Daffodil - Harmonica
# 4. Carousel - Volcano - Eyeglasses
# 5. Banjo - Refrigerator - Tulip
# 6. Monsoon - Chandelier - Skateboard
# 7. Blueprint - Cactus - Saxophone
# 8. Parachute - Whale - Matchstick
# 9. Lantern - Hyena - Popsicle
# 10. Avalanche - Sequin - Microscope
# 11. Coral - Fireplace - Atlas
# 12. Espresso - Falcon - Trowel
# 13. Glue - Swordfish - Gazebo
# 14. Train - Fern - Lipstick
# 15. Kite - Pyramid - Flute
# 16. Cupcake - Stallion - Mosaic
# 17. Telescope - Marigold - Igloo
# 18. Robot - Willow - Perfume
# 19. Castle - Badger - Velvet
# 20. Sundial - Gazelle - Trombone
# 21. Galaxy - Cauldron - Zebra
# 22. Volcano - Broccoli - Diary
# 23. Oyster - Viaduct - Harmonica
# 24. Sledgehammer - Peony - Pizza
# 25. Needle - Rhino - Basketball
# 26. Compass - Gerbil - Muffin
# 27. Echo - Cello - Popcorn
# 28. Bison - Bathtub - Fedora
# 29. Acorn - Fountain - Clarinet
# 30. Albatross - Teapot - Dynamite
# 31. Sandal - Sequoia - Windmill
# 32. Lobster - Typewriter - Prism
# 33. Prism - Crocodile - Flip-flop
# 34. Urn - Porcupine - Baguette
# 35. Balloon - Tiger - Tapestry
# 36. Canoe - Lilac - Pendulum
# 37. Shoelace - Elephant - Disco ball
# 38. Shovel - Orchid - Billboard
# 39. Chimney - Butter - Saxophone
# 40. Hatchet - Seahorse - Hat
# 41. Walnut - Castle - Marmalade
# 42. Squirrel - Bridge - Accordion
# 43. Silk - Sparrow - Lawnmower
# 44. Scissors - Mermaid - Jetty
# 45. Stapler - Platypus - Doughnut
# 46. Eagle - Espresso - Terrarium
# 47. Meteor - Peacock - Envelope
# 48. Sundial - Lobster - Journal
# 49. Croissant - Tulip - Taxi
# 50. Bonsai - Bicycle - Clock
# 51. Otter - Quilt - Trumpet
# 52. Apricot - Hermit crab - Suitcase
# 53. Maple - Panda - Sunscreen
# 54. Subway - Jackal - Umbrella
# 55. Butterfly - Peppermint - Rope ladder
# 56. Raven - Compass - Bonfire
# 57. Gondola - Lemur - Stopwatch
# 58. Hailstorm - Gummy bear - Harp
# 59. Sailboat - Mustang - Oil painting
# 60. Oboe - Dandelion - Lampshade
# 61. Warehouse - Gazpacho - Dinosaur
# 62. Fjord - Geranium - Toolbox
# 63. Windchime - Falcon - Marmalade
# 64. Parrot - Beanie - Treadmill
# 65. Coconut - Antelope - Cufflink
# 66. Totem pole - Pigeon - Earmuffs
# 67. Wardrobe - Maple - Scuba
# 68. Snail - Missile - Pancake
# 69. Caravan - Porpoise - Hatchet
# 70. Bamboo - Cheetah - Hairbrush
# 71. Telescope - Anemone - Klaxon
# 72. Chimera - Cupcake - Wrench
# 73. Sunflower - Racquet - Passport
# 74. Domino - Kiwi - Briefcase
# 75. Pomelo - Sphinx - Paperclip
# 76. Goblin - Redwood - Camcorder
# 77. Minaret - Cabbage - Yo-yo
# 78. Nutmeg - Orangutan - Pickaxe
# 79. Licorice - Coyote - Zamboni
# 80. Penguin - Tuxedo - Wind chime
# 81. Flamingo - Biscotti - Vault
# 82. Hammock - Chipmunk - Spatula
# 83. Spelunker - Coriander - Tablet
# 84. Llama - Sequoia - Tape measure
# 85. Mimosa - Yak - Snow globe
# 86. Quasar - Dromedary - Holster
# 87. Pencil - Marzipan - Turret
# 88. Gecko - Cantaloupe - Plaster
# 89. Seahawk - Rhubarb - Perfume
# 90. Bouquet - Mansion - Salamander
# 91. Falcon - Origami - Asphalt
# 92. Cucumber - Lantern - Mint
# 93. Doorknob - Carnation - Chess piece
# 94. Cashew - Gondola - Beach ball
# 95. Hammock - Broom - Leotard
# 96. Kiwi - Sphinx - Paperweight
# 97. Anchovy - Beet - Moped
# 98. Brownie - Tornado - Necklace
# 99. Sequoia - Kiwi - Origami
# 100. Magnet - Parrot - Snowflake
# 101. Waffle - Pearl - Firework
# 102. Topaz - Lighthouse - Bandana
# 103. Raptor - Hydrangea - Pencil
# 104. Obsidian - Chimney - Poncho
# 105. Giraffe - Tempest - Corkscrew
# 106. Moth - Billboard - Teacup
# 107. Mandarin - Cobweb - Lifeguard
# 108. Caboose - Flannel - Peppercorn
# 109. Easel - Bison - Calculator
# 110. Notebook - Kelp - Raspberry
# 111. Jellyfish - Scroll - Sunglasses
# 112. Bamboo - Fedora - Giraffe
# 113. Dew - Hyacinth - Stopwatch
# 114. Seagull - Canopy - Harmonica
# 115. Cricket - Brownie - Elevator
# 116. Peacock - Stopwatch - Tornado
# 117. Hedgehog - Sugar - Postcard
# 118. Komodo - Wasp - Firefly
# 119. Turnip - Mandolin - Fireman
# 120. Horseshoe - Ribbon - Pancake
# 121. Bassoon - Chimpanzee - Silo
# 122. Satsuma - Witch - Glider
# 123. Trombone - Puddle - Kettle
# 124. Jack-o'-lantern - Fedora - Raincoat
# 125. Apron - Bungalow - Dromedary
# 126. Birch - Marsh - Typewriter
# 127. Cobra - Paddle - Paintbrush
# 128. Rudder - Sunbeam - Velvet
# 129. Shoehorn - Sushi - Snapdragon
# 130. Saffron - Plum - Bat
# 131. Blueberry - Cavern - Script
# 132. Butterfly - Cactus - Domino
# 133. Sequin - Eddy - Trophy
# 134. Espresso - Monsoon - Scarecrow
# 135. Lantern - Peony - Spice
# 136. Beagle - Lava lamp - Crayon
# 137. Ukulele - Bellflower - Compass
# 138. Graphite - Millipede - Satchel
# 139. Incense - Lemon - Rainforest
# 140. Carrot - Firefly - Grater
# 141. Dandelion - Monocle - Pylon
# 142. Ebony - Iguana - Wetsuit
# 143. Locket - Spearmint - Owl
# 144. Marble - Dolphin - Shoestring
# 145. Turquoise - Harpsichord - Balustrade
# 146. Aardvark - Waffle - Carriage
# 147. Barometer - Gazelle - Accordion
# 148. Chisel - Lotus - Archipelago
# 149. Igloo - Trebuchet - Fiddle
# 150. Jellybean - Lighthouse - Molecule
# 151. Kimono - Viola - Abacus
# 152. Lemonade - Otter - Vault
# 153. Mandrill - Spatula - Evergreen
# 154. Nebula - Pedestal - Goldfish
# 155. Oregano - Horseshoe - Trenchcoat
# 156. Pancake - Iridium - Trampoline
# 157. Quiver - Rust - Sapphire
# 158. Rhombus - Shuttlecock - Beaker
# 159. Snorkel - Tundra - Harmonium
# 160. Thimble - Uvula - Velocipede
# 161. Ultraviolet - Vortex - Windsock
# 162. Vellum - Wombat - Xylophone
# 163. Wisteria - Xanadu - Yurt
# 164. Xenon - Yacht - Zeppelin
# 165. Yarn - Zinnia - Aquarium
# 166. Zealot - Atom - Bundt cake
# 167. Brocade - Cymbal - Driftwood
# 168. Chrysanthemum - Derringer - Eelpout
# 169. Dewdrop - Escalator - Firebrand
# 170. Elbow - Fandango - Goulash
# 171. Fennel - Gargoyle - Hobnail
# 172. Garland - Harpoon - Inkwell
# 173. Hibiscus - Iceberg - Jackknife
# 174. Impala - Jigsaw - Kaleidoscope
# 175. Kelp - Limerick - Monsoon
# 176. Lagoon - Marmot - Novella
# 177. Napkin - Oatcake - Porthole
# 178. Origami - Pangolin - Quasar
# 179. Pecan - Quinoa - Ridge
# 180. Quilt - Ravioli - Satchel
# 181. Rosemary - Serenade - Teacup
# 182. Sarsaparilla - Toadstool - Ubiquity
# 183. Turnstile - Universe - Vellum
# 184. Unicycle - Vanilla - Willow
# 185. Vermicelli - Wren - Xebec
# 186. Wanderlust - Xenolith - Yoke
# 187. Xylograph - Yarrow - Zephyr
# 188. Yodel - Zamboni - Acrobat
# 189. Zeppelin - Afternoon - Biscuit
# 190. Alphabet - Blizzard - Candlestick
# 191. Battery - Cinnamon - Dragonfly
# 192. Dandelion - Eclipse - Flannel
# 193. Earring - Foam - Grapeshot
# 194. Frigate - Glacier - Heliotrope
# 195. Gargoyle - Horizon - Illustration
# 196. Harp - Incubator - Jamboree
# 197. Iguana - Jackpot - Kneecap
# 198. Jelly - Keystone - Lantern
# 199. Kangaroo - Lullaby - Magnet
# 200. Lemon - Monocle - Nebula
# 201. Moccasin - Nectar - Oasis
# 202. Notebook - Ocelot - Parable
# 203. Octopus - Papyrus - Quilt
# 204. Platypus - Quince - Resin
# 205. Rhubarb - Sapphire - Tangerine
# 206. Sequoia - Tarantula - Umbrella
# 207. Utopia - Vineyard - Whistle
# 208. Violin - Wasp - Xenops
# 209. Watchtower - Xylophone - Yo-yo
# 210. Yucca - Ziggurat - Amethyst
# 211. Zebra - Ambrosia - Bobcat
# 212. Cabbage - Duckling - Eucalyptus
# 213. Dumpling - Eraser - Fossil
# 214. Fjord - Guillotine - Hologram
# 215. Guitar - Hydrant - Invoice
# 216. Iris - Javelin - Knot
# 217. Knapsack - Lavender - Mammoth
# 218. Maple - Neptune - Oboe
# 219. Nutcracker - Opal - Palette
# 220. Paddle - Quokka - Ripple
# 221. Ragdoll - Sapphire - Teapot
# 222. Snapdragon - Toffee - Umpire
# 223. Umbra - Valkyrie - Waffle
# 224. Vanilla - Wind - Xanadu
# 225. Wombat - Xerox - Yacht
# 226. Yak - Zamboni - Apricot
# 227. Zephyr - Aquarium - Balloon
# 228. Bayonet - Croissant - Dewdrop
# 229. Drone - Espresso - Fountain
# 230. Foxglove - Garland - Heirloom
# 231. Helmet - Ivory - Jester
# 232. Jackal - Kelpie - Labyrinth
# 233. Lantern - Mosaic - Nectarine
# 234. Needle - Oracle - Pegasus
# 235. Quasar - Rhomboid - Serendipity
# 236. Salamander - Telescope - Unicorn
# 237. Umbrella - Vervain - Willow
# 238. Vortex - Walrus - Xenolith
# 239. Whirlpool - Xenon - Yodel
# 240. Yew - Zircon - Alpine
# 241. Azalea - Boulevard - Canopy
# 242. Crest - Dune - Equinox
# 243. Espresso - Filigree - Genesis
# 244. Halo - Infinity - Juniper
# 245. Keystone - Lava - Mirage
# 246. Marigold - Nimbus - Oracle
# 247. Opulence - Pinnacle - Quiver
# 248. Quarry - Rhapsody - Silhouette
# 249. Sapphire - Tidal - Utopian
# 250. Unicorn - Verdant - Whimsy
# 251. Vista - Willow - Xenial
# 252. Waterfall - Xenophobia - Yucca
# 253. Zenith - Amaranth - Breeze
# 254. Barracuda - Crescent - Drizzle
# 255. Dove - Ember - Fern
# 256. Glade - Horizon - Icicle
# 257. Jasmine - Kite - Lagoon
# 258. Lotus - Moonbeam - Nectar
# 259. Oasis - Pheasant - Quill
# 260. Quasar - Reef - Spruce
# 261. Torrent - Uplift - Vale
# 262. Velvet - Winter - Xenia
# 263. Xylo - Yellow - Zephyr
# 264. Zany - Archipelago - Bubble
# 265. Beetle - Crystal - Dandelion
# 266. Eclipse - Fable - Galaxy
# 267. Gingham - Huckleberry - Iris
# 268. Jigsaw - Kiln - Lyric
# 269. Meadow - Nymph - Opal
# 270. Paddock - Quilt - Riddle
# 271. Sable - Tundra - Umbra
# 272. Umber - Viola - Wigwam
# 273. Willow - Xeric - Yarrow
# 274. Yelp - Zest - Arbor
# 275. Beryl - Cloudburst - Dew
# 276. Dragon - Elm - Fiber
# 277. Firefly - Gorge - Halo
# 278. Hydrangea - Impulse - Juncture
# 279. Kernel - Ledge - Meadow
# 280. Nimbus - Overture - Prism
# 281. Pulsar - Quest - Rhythm
# 282. Solstice - Tulip - Universe
# 283. Urchin - Verve - Whisper
# 284. Wisp - Xanthic - Yield
# 285. Yucca - Zephyr - Azure
# 286. Agate - Buckle - Cascade
# 287. Delta - Empyrean - Frost
# 288. Garnet - Horizon - Ink
# 289. Jambalaya - Knave - Luminous
# 290. Minuet - Nostalgia - Orbit
# 291. Opine - Palladium - Quasar
# 292. Ravel - Soliloquy - Thistle
# 293. Tether - Umami - Vent
# 294. Vignette - Waffle - Xenon
# 295. Well - Yodel - Zestful
# 296. Zag - Arbor - Binnacle
# 297. Cavern - Damask - Eclipse
# 298. Effigy - Filament - Glitch
# 299. Glimmer - Hearth - Icon
# 300. Iridescent - Julep - Keystone

# %%
def per_run_aggregate_summary(results):
    detailed_data = []
    for run_index, result in enumerate(results, start=1):
        trisociations = result['trisociations'].strip()
        trisociation_list = trisociations.split('\n')

        for trisociation_index, trisociation in enumerate(trisociation_list, start=1):
            words = re.sub(r'^\d+\.\s*', '', trisociation).replace(' - ', ' ').split()
            for word in words:
                detailed_data.append({'run': run_index, 'word': word})

    df = pd.DataFrame(detailed_data)

    summary_stats = []
    unique_runs = df['run'].unique()
    
    for run in sorted(unique_runs):
        run_df = df[df['run'] == run]
        
        total_words = run_df.shape[0]
        total_unique_words = run_df['word'].nunique()
        total_duplicates = run_df[run_df.duplicated('word', keep=False)]['word'].nunique()
        
        if not run_df[run_df.duplicated('word', keep=False)].empty:
            mode_duplicate = run_df[run_df.duplicated('word', keep=False)]['word'].value_counts().idxmax()
            max_dup_freq = run_df[run_df.duplicated('word', keep=False)]['word'].value_counts().max()
            modal_dup_freq = run_df[run_df.duplicated('word', keep=False)]['word'].value_counts().mode()[0]
        else:
            mode_duplicate = 'None'
            max_dup_freq = 0
            modal_dup_freq = 0
        
        min_dup_freq = run_df[run_df.duplicated('word', keep=False)]['word'].value_counts().min() if not run_df[run_df.duplicated('word', keep=False)].empty else 0
        
        summary_stats.append({
            'Total Words': total_words,
            'Total Unique Words': total_unique_words,
            'Total Duplicates': total_duplicates,
            'Max Dup Word': mode_duplicate,
            'Max Dup Freq': max_dup_freq,
            'Modal Dup Freq': modal_dup_freq,
            'Min Dup Freq': min_dup_freq
        })
    
    summary_df = pd.DataFrame(summary_stats, index=[f'Run {run}' for run in sorted(unique_runs)])
    
    # Apply styling
    styled_df = summary_df.style\
        .format({'Total Words': "{:}", 'Total Unique Words': "{:}", 'Total Duplicates': "{:}", 
                 'Max Dup Word': "{}", 'Max Dup Freq': "{:}", 'Modal Dup Freq': "{:}", 'Min Dup Freq': "{:}"})\
        .set_table_styles([{
            'selector': 'th',
            'props': [
                ('background-color', '#f4f4f4'),
                ('color', '#6d6d6d'),
                ('font-weight', 'bold')
            ]}])\
        .set_caption("Summary Statistics per Run")\
        .set_properties(**{'text-align': 'left'})

    return styled_df

# Assuming 'results' is populated from previous code blocks
# Simply call the function to display the styled DataFrame in your Jupyter Notebook
per_run_aggregate_summary_styled = per_run_aggregate_summary(results)
per_run_aggregate_summary_styled
# Out:
# <style type="text/css">
# #T_c8705 th {
#   background-color: #f4f4f4;
#   color: #6d6d6d;
#   font-weight: bold;
# }
# #T_c8705_row0_col0, #T_c8705_row0_col1, #T_c8705_row0_col2, #T_c8705_row0_col3, #T_c8705_row0_col4, #T_c8705_row0_col5, #T_c8705_row0_col6, #T_c8705_row1_col0, #T_c8705_row1_col1, #T_c8705_row1_col2, #T_c8705_row1_col3, #T_c8705_row1_col4, #T_c8705_row1_col5, #T_c8705_row1_col6, #T_c8705_row2_col0, #T_c8705_row2_col1, #T_c8705_row2_col2, #T_c8705_row2_col3, #T_c8705_row2_col4, #T_c8705_row2_col5, #T_c8705_row2_col6 {
#   text-align: left;
# }
# </style>
# <table id="T_c8705">
#   <caption>Summary Statistics per Run</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8705_level0_col0" class="col_heading level0 col0" >Total Words</th>
#       <th id="T_c8705_level0_col1" class="col_heading level0 col1" >Total Unique Words</th>
#       <th id="T_c8705_level0_col2" class="col_heading level0 col2" >Total Duplicates</th>
#       <th id="T_c8705_level0_col3" class="col_heading level0 col3" >Max Dup Word</th>
#       <th id="T_c8705_level0_col4" class="col_heading level0 col4" >Max Dup Freq</th>
#       <th id="T_c8705_level0_col5" class="col_heading level0 col5" >Modal Dup Freq</th>
#       <th id="T_c8705_level0_col6" class="col_heading level0 col6" >Min Dup Freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8705_level0_row0" class="row_heading level0 row0" >Run 1</th>
#       <td id="T_c8705_row0_col0" class="data row0 col0" >900</td>
#       <td id="T_c8705_row0_col1" class="data row0 col1" >735</td>
#       <td id="T_c8705_row0_col2" class="data row0 col2" >122</td>
#       <td id="T_c8705_row0_col3" class="data row0 col3" >Glacier</td>
#       <td id="T_c8705_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_c8705_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_c8705_row0_col6" class="data row0 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c8705_level0_row1" class="row_heading level0 row1" >Run 2</th>
#       <td id="T_c8705_row1_col0" class="data row1 col0" >941</td>
#       <td id="T_c8705_row1_col1" class="data row1 col1" >620</td>
#       <td id="T_c8705_row1_col2" class="data row1 col2" >167</td>
#       <td id="T_c8705_row1_col3" class="data row1 col3" >Soda</td>
#       <td id="T_c8705_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_c8705_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_c8705_row1_col6" class="data row1 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c8705_level0_row2" class="row_heading level0 row2" >Run 3</th>
#       <td id="T_c8705_row2_col0" class="data row2 col0" >900</td>
#       <td id="T_c8705_row2_col1" class="data row2 col1" >693</td>
#       <td id="T_c8705_row2_col2" class="data row2 col2" >137</td>
#       <td id="T_c8705_row2_col3" class="data row2 col3" >Zenith</td>
#       <td id="T_c8705_row2_col4" class="data row2 col4" >7</td>
#       <td id="T_c8705_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_c8705_row2_col6" class="data row2 col6" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
# task 1 : display the duplicates in a nicer visual. a table maybe is simple with pandas?
# task 2 : can the duplicates code handle all the prompt type returns
# task 3 : do the mega trisociation prompt and see if any real difference along with language
# task 4 : do cosine similarity
# task 5 : display the base run data in a nicer format
# task 6 : what about a word cloud?
# task 7 : compare it to just generating a word list from a txt file
# task 8 : maybe modify the format prompt to be something like try diverse variations. diverse_prompt.
# task 9 : vary temperature, top p. Maybe that's a separate experiment. maybe that's the main one here.
# task 10 : display each run details before computing the visual
# task 11 : try lousier GPT Models for cheaper inference

# %%
def detailed_duplicate_analysis(results):
    data = []
    for run_index, result in enumerate(results, start=1):
        trisociations = result['trisociations'].strip()
        trisociation_list = trisociations.split('\n')

        for trisociation_index, trisociation in enumerate(trisociation_list, start=1):
            words = re.sub(r'^\d+\.\s*', '', trisociation).replace(' - ', ' ').split()
            for word in words:
                data.append({'run': run_index, 'trisociation_index': trisociation_index, 'word': word})
    
    df = pd.DataFrame(data)
    
    # Identifying duplicates
    duplicate_words = df[df.duplicated('word', keep=False)]
    
    # Count and detail aggregation for duplicates
    detailed_duplicates = duplicate_words.groupby('word').agg(
        count=('word', 'size'),  # Use 'size' instead of 'count' for aggregation to get the actual count of rows
        runs=('run', lambda x: sorted(list(set(x)))),
        trisociation_indices=('trisociation_index', lambda x: sorted(list(set(x))))
    ).reset_index()

    # Sorting by 'count' in descending order
    detailed_duplicates = detailed_duplicates.sort_values(by='count', ascending=False).reset_index(drop=True)

    return detailed_duplicates

detailed_df = detailed_duplicate_analysis(results)

styled_df = detailed_df.style\
    .format({'count': '{:.0f}'})\
    .background_gradient(subset='count', cmap='Blues')\
    .set_properties(**{'text-align': 'left'})\
    .set_table_styles([dict(selector='th', props=[('text-align', 'left')])])\
    .highlight_max(subset='count', color='green')\
    .highlight_min(subset='count', color='red')

styled_df
# Out:
# <style type="text/css">
# #T_2e733 th {
#   text-align: left;
# }
# #T_2e733_row0_col0, #T_2e733_row0_col2, #T_2e733_row0_col3, #T_2e733_row1_col0, #T_2e733_row1_col2, #T_2e733_row1_col3, #T_2e733_row2_col0, #T_2e733_row2_col2, #T_2e733_row2_col3, #T_2e733_row3_col0, #T_2e733_row3_col2, #T_2e733_row3_col3, #T_2e733_row4_col0, #T_2e733_row4_col2, #T_2e733_row4_col3, #T_2e733_row5_col0, #T_2e733_row5_col2, #T_2e733_row5_col3, #T_2e733_row6_col0, #T_2e733_row6_col2, #T_2e733_row6_col3, #T_2e733_row7_col0, #T_2e733_row7_col2, #T_2e733_row7_col3, #T_2e733_row8_col0, #T_2e733_row8_col2, #T_2e733_row8_col3, #T_2e733_row9_col0, #T_2e733_row9_col2, #T_2e733_row9_col3, #T_2e733_row10_col0, #T_2e733_row10_col2, #T_2e733_row10_col3, #T_2e733_row11_col0, #T_2e733_row11_col2, #T_2e733_row11_col3, #T_2e733_row12_col0, #T_2e733_row12_col2, #T_2e733_row12_col3, #T_2e733_row13_col0, #T_2e733_row13_col2, #T_2e733_row13_col3, #T_2e733_row14_col0, #T_2e733_row14_col2, #T_2e733_row14_col3, #T_2e733_row15_col0, #T_2e733_row15_col2, #T_2e733_row15_col3, #T_2e733_row16_col0, #T_2e733_row16_col2, #T_2e733_row16_col3, #T_2e733_row17_col0, #T_2e733_row17_col2, #T_2e733_row17_col3, #T_2e733_row18_col0, #T_2e733_row18_col2, #T_2e733_row18_col3, #T_2e733_row19_col0, #T_2e733_row19_col2, #T_2e733_row19_col3, #T_2e733_row20_col0, #T_2e733_row20_col2, #T_2e733_row20_col3, #T_2e733_row21_col0, #T_2e733_row21_col2, #T_2e733_row21_col3, #T_2e733_row22_col0, #T_2e733_row22_col2, #T_2e733_row22_col3, #T_2e733_row23_col0, #T_2e733_row23_col2, #T_2e733_row23_col3, #T_2e733_row24_col0, #T_2e733_row24_col2, #T_2e733_row24_col3, #T_2e733_row25_col0, #T_2e733_row25_col2, #T_2e733_row25_col3, #T_2e733_row26_col0, #T_2e733_row26_col2, #T_2e733_row26_col3, #T_2e733_row27_col0, #T_2e733_row27_col2, #T_2e733_row27_col3, #T_2e733_row28_col0, #T_2e733_row28_col2, #T_2e733_row28_col3, #T_2e733_row29_col0, #T_2e733_row29_col2, #T_2e733_row29_col3, #T_2e733_row30_col0, #T_2e733_row30_col2, #T_2e733_row30_col3, #T_2e733_row31_col0, #T_2e733_row31_col2, #T_2e733_row31_col3, #T_2e733_row32_col0, #T_2e733_row32_col2, #T_2e733_row32_col3, #T_2e733_row33_col0, #T_2e733_row33_col2, #T_2e733_row33_col3, #T_2e733_row34_col0, #T_2e733_row34_col2, #T_2e733_row34_col3, #T_2e733_row35_col0, #T_2e733_row35_col2, #T_2e733_row35_col3, #T_2e733_row36_col0, #T_2e733_row36_col2, #T_2e733_row36_col3, #T_2e733_row37_col0, #T_2e733_row37_col2, #T_2e733_row37_col3, #T_2e733_row38_col0, #T_2e733_row38_col2, #T_2e733_row38_col3, #T_2e733_row39_col0, #T_2e733_row39_col2, #T_2e733_row39_col3, #T_2e733_row40_col0, #T_2e733_row40_col2, #T_2e733_row40_col3, #T_2e733_row41_col0, #T_2e733_row41_col2, #T_2e733_row41_col3, #T_2e733_row42_col0, #T_2e733_row42_col2, #T_2e733_row42_col3, #T_2e733_row43_col0, #T_2e733_row43_col2, #T_2e733_row43_col3, #T_2e733_row44_col0, #T_2e733_row44_col2, #T_2e733_row44_col3, #T_2e733_row45_col0, #T_2e733_row45_col2, #T_2e733_row45_col3, #T_2e733_row46_col0, #T_2e733_row46_col2, #T_2e733_row46_col3, #T_2e733_row47_col0, #T_2e733_row47_col2, #T_2e733_row47_col3, #T_2e733_row48_col0, #T_2e733_row48_col2, #T_2e733_row48_col3, #T_2e733_row49_col0, #T_2e733_row49_col2, #T_2e733_row49_col3, #T_2e733_row50_col0, #T_2e733_row50_col2, #T_2e733_row50_col3, #T_2e733_row51_col0, #T_2e733_row51_col2, #T_2e733_row51_col3, #T_2e733_row52_col0, #T_2e733_row52_col2, #T_2e733_row52_col3, #T_2e733_row53_col0, #T_2e733_row53_col2, #T_2e733_row53_col3, #T_2e733_row54_col0, #T_2e733_row54_col2, #T_2e733_row54_col3, #T_2e733_row55_col0, #T_2e733_row55_col2, #T_2e733_row55_col3, #T_2e733_row56_col0, #T_2e733_row56_col2, #T_2e733_row56_col3, #T_2e733_row57_col0, #T_2e733_row57_col2, #T_2e733_row57_col3, #T_2e733_row58_col0, #T_2e733_row58_col2, #T_2e733_row58_col3, #T_2e733_row59_col0, #T_2e733_row59_col2, #T_2e733_row59_col3, #T_2e733_row60_col0, #T_2e733_row60_col2, #T_2e733_row60_col3, #T_2e733_row61_col0, #T_2e733_row61_col2, #T_2e733_row61_col3, #T_2e733_row62_col0, #T_2e733_row62_col2, #T_2e733_row62_col3, #T_2e733_row63_col0, #T_2e733_row63_col2, #T_2e733_row63_col3 ...

# %%
# trisociation prompt

TRISOCIATION_PROMPT=f"""

---

**Strict Exclusion List**
_Before embarking on the task, it is imperative to note that the following words are strictly prohibited from use in the trisociations:_

- Hiraeth
- Zephyr
- Ubuntu
- Petrichor
- Yugen
- Saudade
- Komorebi
- Tsundoku
- Cwtch
- Wabi-Sabi
- Mamihlapinatapai
- Fernweh
- Flaneur
- Hygge
- Mangata
- Samadhi
- Apricity

---

**Guidelines for Diverse and Unique Trisociations:**
As an advanced algorithm with access to a vast vector database of semantic embeddings, your role is to facilitate the trisociation process — a creative endeavor that interlaces three semantically distant concepts. Your mission is to construct trisociations that are linguistically diverse and conceptually distinctive, avoiding commonly used words and uncovering hidden linguistic gems.

---

_Please ensure that none of the words in the strict exclusion list are used in the trisociations._

1. **Explore the Uncommon**: Avoid frequently chosen words and seek out less common vocabulary.
2. **Prioritize Lesser-Known Vocabulary**: Focus on words that are less commonly used in creative writing, poetry, and literary contexts, aiming to uncover unique and underrepresented words.
3. **Thematic Diversity**: Incorporate words from themes like technology, mythology, professions, emotions, and weather phenomena, avoiding the obvious choices.
4. **Historical and Cultural Significance**: Choose words with historical or cultural resonance, especially those that are less known or underrepresented.
5. **Vibrant Language Use**: Include regional dialects or slang, with a focus on those that are less frequently used.
6. **Varied Parts of Speech**: Mix nouns, verbs, adjectives, and adverbs, especially those that are less common in trisociation contexts.
7. **Sensory Exploration**: Select sensory words that are vivid yet not the usual go-to options.
8. **Abstract and Tangible Fusion**: Blend abstract concepts with concrete items in unconventional ways.
9. **Language Family Diversity**: Draw from a wide array of language families, especially focusing on those less represented in common discourse.
10. **Creative Figurative Language**: Use metaphors, similes, and symbolic language, avoiding clichés and common expressions.
11. **Wide Emotional Range**: Cover a spectrum of emotions with less typical word choices.
12. **Temporal and Cultural Fusion**: Connect different eras and cultures, going beyond well-trodden paths.
13. **Lesser-Known Language Exploration**: Seek out words from lesser-known languages and dialects.
14. **Balanced Elements**: Ensure that each word contributes equally to the trisociation, without any overshadowing the others.
15. **Semantic Uniqueness**: Ensure that each trisociation stands out in its conceptual composition, distinct from typical combinations.
16. **Language Identification**: In each trisociation, identify the languages of the chosen words. This highlights the linguistic diversity and encourages the exploration of a variety of languages, including lesser-known ones.

---

Task:

Generate {n} Trisociations adhering to the above guidelines. Each trisociation should be a creative blend of three semantically distant nouns, showcasing linguistic innovation and conceptual uniqueness. 
The words in the exclusion list should not be part of any trisociation. No additional comments, explanations or elaborations beyond the trisociation itself.

Output Format :

1. Word (language) - Word (language) - Word (language)
2. Word (language) - Word (language) - Word (language)
...

"""
